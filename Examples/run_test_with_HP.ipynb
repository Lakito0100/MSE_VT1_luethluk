# %%
from pathlib import Path
import sys
import numpy as np
from CoolProp.HumidAirProp import HAPropsSI
from CoolProp.CoolProp import PropsSI
sys.path.insert(0, str(Path.cwd().parent))
from Framework.core.config import CaseConfig, GridShape, HeatPump
from Framework.core.geometry import FinnTubedHX
from Framework.models import Frostmodell_V1
from Framework.runtime.simulator_V2 import Simulator
from Framework.visualisation import plot
from Framework.runtime.recorder import ResultRecorder

# %% [markdown]
# # Case Definieren

# %%
sim_run = True
read_data = True

#air
T_a = 20.0
P = 101325
RH = 0.1
v_a = 1.2

#refrigerant
w_amb_in = HAPropsSI('W','T',T_a+273.15,'P',P,'R', RH)
rho_amb_in = 1.0 / HAPropsSI("Vha","T",T_a+273.15,"P",P,"R",RH)

refrigerant = "R134a"
#at evaportor
x_in = 0.5
p_ref_in = PropsSI("P", "T", T_a + 273.15, "Q", x_in, refrigerant)
h_ref_in = PropsSI("H", "T", T_a + 273.15, "Q", x_in, refrigerant)

#water
T_in_water = 30.0
N_cond = 22

#at condenser
p_ref_cond = PropsSI("P", "T", T_in_water + 273.15, "Q", x_in, refrigerant)
h_ref_cond = PropsSI("H", "T", T_in_water + 273.15, "Q", x_in, refrigerant)

geom = FinnTubedHX(
    n_seg_l = 2,        # -
    n_seg_r = 20,        # -
    stacks = 200,         # -
    n_fin = 2,           # -
    l_fin = 0.022,          # m
    h_fin = 0.022,          # m
    fin_thickness = 0.0002,    # m
    fin_pitch_cc = 0.0032,          # m
    d_tube_a = 0.00952,          # m
    tube_thickness = 0.0005,       # m
    lambda_fin = 237,            # W/mK
    rho_solid = 8000,            # kg/m3
    c_solid = 500,               # J/kgK
    CP = "row_serpentine"
)

gs = GridShape(
    t_end = 1.5*60.0,      # s endtime
    dt = 2.0,           # s time step
    store_grid_every_x_it = 10,

    nx = 100,
    nr = 100,
    ntheta = 90,

    #Model Setup
    cal_steady_state = False,
    cal_air = True,
    cal_frost = False,
    cal_ref = True
)

cfg = CaseConfig(
    # air data
    m_dot = v_a*rho_amb_in*(geom.h_fin*geom.fin_gap()*geom.n_seg_r*geom.stacks), # Backup massflow if no fan is used
    T_a = T_a,          # °C temperature air
    v_a = v_a,          # m/s velocity air
    p_a = P,            # Pa pressure air
    RH = RH,            # relative humidity air
    w_amb = w_amb_in,          # kg/kg water vapor moisture content
    rho_amb = rho_amb_in,      # kg/m^3 density air
    v_kin = 1.5e-5,     # m^2/s kinematic viscosity air
    lam = 0.025,        # W/mK heat conduction coefficient air
    c_p_a = 1000,       # J/kgK heat capacity air
    D_std = 2.2e-5,     # m^2/s water vapor diffusion coefficient
    C = 900,            # 1/s empirical water vapor absorbed coefficient
    isv = 2830000,      # J/kg latent heat of desublimation

    # fan model
    use_fan = True,
    fan_dp0 = 150.0,
    fan_V0 = v_a*(geom.h_fin*geom.fin_gap()*geom.n_seg_r*geom.stacks),
    dp_clean = 40.0,


    # refrigerant data
    ref_str = refrigerant,
    T_tube = T_a,    # °C tube temperature
    T_ref = T_a,     # °C tube temperature
    p_ref = p_ref_in,      # Pa Kältemitteldruck
    h_ref = h_ref_in,          # J/kg spezifische Enthalpie
    m_dot_ref = 0,      # kg/s Massenstrom am Inlet (invalid)
    m_dot_ref_out = 0,      # kg/s Massenstrom am Outlet (invalid)
    x_ref = x_in,           # Dampfqualität (0..1), NaN falls einphasig

    # ice data
    rho_i = 920,        # kg/m^3 ice density
    h_sub= 2830000,     # J/kg latent heat of ablimation for water vapor
)

HP = HeatPump(
    N_cond=N_cond,
    p_ref_cond = p_ref_cond,
    h_ref_cond = np.full(N_cond, h_ref_cond, dtype=float),
    T_wall = np.full(N_cond, T_in_water, dtype=float),
    T_water = np.full(N_cond, T_in_water, dtype=float),

    A_flow_cond = 0.01,
    dx_cond = 0.5/N_cond,
    t_plate = 0.001,
    height_cond=1.0,
    A_plate = 3.65,
    c_plate = 500,
    rho_plate = 8000.0,
    lamda_plate = 50.0,

    #water
    T_in_water = T_in_water,
    m_water = 0.35,
    c_water = 4200,
    rho_water = 997
)

plot.plot_finned_tube_side(geom)
print(f"Surface area Evaporator = {geom.A_one_segment()*geom.n_seg_r*geom.n_seg_l*geom.stacks:.2f} m2")
print(f"Surface area Condenser = {HP.A_plate:.2f} m2")
# Out:
# Surface area Evaporator = 7.32 m2
# Surface area Condenser = 3.65 m2

# %% [markdown]
# # Simulation laufen lassen

# %%
result_file = "results_test"

if sim_run:
    sim = Simulator(geom,cfg,HP,result_file)
    results = sim.run(cfg, geom, gs, Frostmodell_V1)
# Out:
# Time Step: 1	 Time: 0.0 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=56, mean T_evap=16.14 °C, mean T_tube_evap=17.42 °C, Q_evap=4654.97 W, Q_cond=2293.61 W, ct=3.059 s)
# Cycle time for time step 1: 4.0 s
# Time remaining: 3.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 2	 Time: 2.0 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.05 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=203, mean T_evap=16.23 °C, mean T_tube_evap=16.44 °C, Q_evap=789.32 W, Q_cond=3316.38 W, ct=22.118 s)
# Cycle time for time step 2: 22.3 s
# Time remaining: 16.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 3	 Time: 4.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=18.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=65, mean T_evap=15.43 °C, mean T_tube_evap=16.09 °C, Q_evap=1168.31 W, Q_cond=2605.34 W, ct=8.449 s)
# Cycle time for time step 3: 8.6 s
# Time remaining: 6.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 4	 Time: 6.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.19 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=38, mean T_evap=14.83 °C, mean T_tube_evap=15.63 °C, Q_evap=1304.87 W, Q_cond=2725.80 W, ct=3.597 s)
# Cycle time for time step 4: 3.8 s
# Time remaining: 2.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 5	 Time: 8.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.46 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=34, mean T_evap=14.38 °C, mean T_tube_evap=15.21 °C, Q_evap=1411.07 W, Q_cond=2957.39 W, ct=5.161 s)
# Cycle time for time step 5: 5.3 s
# Time remaining: 3.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 6	 Time: 10.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.51 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.60 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.65 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.65 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.67 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=63, mean T_evap=13.75 °C, mean T_tube_evap=14.81 °C, Q_evap=1528.91 W, Q_cond=3197.88 W, ct=11.739 s)
# Cycle time for time step 6: 11.9 s
# Time remaining: 8.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 7	 Time: 12.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.72 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=33, mean T_evap=12.64 °C, mean T_tube_evap=14.36 °C, Q_evap=1715.63 W, Q_cond=3348.47 W, ct=2.014 s)
# Cycle time for time step 7: 2.2 s
# Time remaining: 1.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 8	 Time: 14.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.71 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.81 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.82 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=64, mean T_evap=11.30 °C, mean T_tube_evap=13.82 °C, Q_evap=1914.70 W, Q_cond=3559.38 W, ct=5.630 s)
# Cycle time for time step 8: 5.8 s
# Time remaining: 3.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 9	 Time: 16.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.80 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.82 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.87 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.92 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=64, mean T_evap=8.91 °C, mean T_tube_evap=13.11 °C, Q_evap=2272.29 W, Q_cond=3843.57 W, ct=8.549 s)
# Cycle time for time step 9: 8.7 s
# Time remaining: 5.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 10	 Time: 18.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.87 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.92 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.92 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.99 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=77, mean T_evap=4.91 °C, mean T_tube_evap=12.10 °C, Q_evap=2791.53 W, Q_cond=4287.64 W, ct=7.237 s)
# Cycle time for time step 10: 8.0 s
# Time remaining: 4.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 11	 Time: 20.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.87 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.92 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.94 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.94 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=20.06 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=109, mean T_evap=0.19 °C, mean T_tube_evap=10.65 °C, Q_evap=3313.18 W, Q_cond=4960.53 W, ct=13.488 s)
# Cycle time for time step 11: 13.7 s
# Time remaining: 8.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 12	 Time: 22.0 s | 0.4 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.92 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.94 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.94 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=20.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=146, mean T_evap=-12.64 °C, mean T_tube_evap=8.40 °C, Q_evap=4508.56 W, Q_cond=6008.38 W, ct=24.857 s)
# Cycle time for time step 12: 25.1 s
# Time remaining: 14.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 13	 Time: 24.0 s | 0.4 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.94 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.99 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.99 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.99 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.99 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=20.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=439, mean T_evap=-14.98 °C, mean T_tube_evap=3.15 °C, Q_evap=8634.15 W, Q_cond=9068.46 W, ct=59.603 s)
# Cycle time for time step 13: 59.8 s
# Time remaining: 32.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 14	 Time: 26.0 s | 0.4 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=14.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=17.51 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.55 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.80 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.99 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=20.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=20.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=20.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=20.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=20.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=20.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=20.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=21.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=151, mean T_evap=-16.67 °C, mean T_tube_evap=-1.95 °C, Q_evap=7292.87 W, Q_cond=10136.00 W, ct=16.450 s)
# Cycle time for time step 14: 16.6 s
# Time remaining: 8.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 15	 Time: 28.0 s | 0.5 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=7.12 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.94 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=7.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=11.19 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=14.71 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=16.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=18.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.08 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.51 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.87 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.99 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.16 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=85, mean T_evap=-18.81 °C, mean T_tube_evap=-4.16 °C, Q_evap=6271.54 W, Q_cond=9344.52 W, ct=12.860 s)
# Cycle time for time step 15: 13.0 s
# Time remaining: 6.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 16	 Time: 30.0 s | 0.5 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=7.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.92 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=11.73 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=13.55 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=15.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=16.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=17.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=18.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.46 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.68 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.81 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.94 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=87, mean T_evap=-20.48 °C, mean T_tube_evap=-4.66 °C, Q_evap=5522.75 W, Q_cond=8526.12 W, ct=11.361 s)
# Cycle time for time step 16: 11.5 s
# Time remaining: 5.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 17	 Time: 32.0 s | 0.5 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.17 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.94 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=11.71 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=12.52 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=13.45 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=14.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=15.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=16.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# ...
# Seg[1,1] | Air(T=6.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=7.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=12.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=13.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=14.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=15.14 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=15.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=16.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=17.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.82 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=18.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=12, mean T_evap=-18.94 °C, mean T_tube_evap=-8.19 °C, Q_evap=6126.80 W, Q_cond=9066.07 W, ct=1.243 s)
# Cycle time for time step 41: 1.5 s
# Time remaining: 0.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 42	 Time: 82.0 s | 1.4 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=7.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=11.10 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=12.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=13.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=14.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=15.14 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=15.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=16.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=16.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=18.10 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=18.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.61 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=16, mean T_evap=-18.97 °C, mean T_tube_evap=-8.17 °C, Q_evap=6115.38 W, Q_cond=9048.68 W, ct=2.281 s)
# Cycle time for time step 42: 2.5 s
# Time remaining: 0.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 43	 Time: 84.0 s | 1.4 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=11.22 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=12.45 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=13.51 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=14.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=15.19 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=15.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=16.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=16.94 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=18.08 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=18.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.60 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=17, mean T_evap=-18.96 °C, mean T_tube_evap=-8.14 °C, Q_evap=6118.55 W, Q_cond=9044.21 W, ct=3.816 s)
# Cycle time for time step 43: 4.0 s
# Time remaining: 0.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 44	 Time: 86.0 s | 1.4 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.03 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=11.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=12.51 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=13.57 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=14.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=15.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=15.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=16.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=16.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=18.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=18.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.59 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=9, mean T_evap=-18.94 °C, mean T_tube_evap=-8.13 °C, Q_evap=6131.06 W, Q_cond=9051.33 W, ct=0.107 s)
# Cycle time for time step 44: 0.3 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 45	 Time: 88.0 s | 1.5 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=7.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=11.21 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=12.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=13.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=14.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=15.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=15.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=16.51 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=17.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=18.08 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=18.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.59 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=13, mean T_evap=-18.92 °C, mean T_tube_evap=-8.14 °C, Q_evap=6143.63 W, Q_cond=9063.26 W, ct=0.170 s)
# Cycle time for time step 45: 0.4 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 46	 Time: 90.0 s | 1.5 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.55 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.55 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.55 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.55 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.55 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=7.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.59 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=11.13 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=12.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=13.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=14.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=15.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=15.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=16.52 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=17.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=18.10 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=18.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.60 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=10, mean T_evap=-18.90 °C, mean T_tube_evap=-8.16 °C, Q_evap=6149.69 W, Q_cond=9072.59 W, ct=0.958 s)
# Cycle time for time step 46: 1.7 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Simulation ended at 2025-12-23 15:40:17
# Time to complete: 6.0 min

# %% [markdown]
# # Resultate speichen/laden

# %%
if sim_run:
    data = results.data
    results.to_csv(result_file,data)

if read_data:
    data = ResultRecorder.read_results_csv_json(result_file)
    results = ResultRecorder.from_jsonl(result_file)

# %% [markdown]
# # Resultate plotten

# %%
snapshots = results.grid_snapshots

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="v_a",
    source="cfg",
    t_idx=-1,          # letzter Zeitschritt
    title="Geschwindigkeit der Luft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="s_ft",
    source="st",       # aus SimState
    t_idx=-1,          # letzter Zeitschritt
    title="Frostdicke s_ft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_a",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Lufttemperatur T_a über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="w_amb",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="RH",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="relative Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_tube",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur der Wände über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur des Kältemittels über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="h_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Enthalpie des Kältemittels über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="p_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Druck vom Kältemittel über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="x_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="X des Kältemittel über alle Segmente",
    cmap="viridis"
)

# %%
plot.plot_logph_cycles(
    ref=cfg.ref_str,
    t=data["t"],
    cycle_ph=data["cycle_ph"],
    at_time=gs.t_end,
    isotherms=True,
    grid="none"
)

plot.plot_logph_cycles(
    ref=cfg.ref_str,
    t=data["t"],
    cycle_ph=data["cycle_ph"],
    t_start=60.0,
    t_end=gs.t_end,
    every_s=60.0,   # alle 60 s ein Kreisprozess
    isotherms=True,
    grid="none",
    title="Kreisprozess über die Zeit"
)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['EER'],
              xlabel="Zeit [s]", ylabel="EER",
              title=f"EER", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['COP'],
              xlabel="Zeit [s]", ylabel="COP",
              title=f"COP", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['mean_s_ft'],
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Durchschnittliche Frostdicke", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['m_dot_air'],
              xlabel="Zeit [s]", ylabel="Massenfluss [kg/s]",
              title=f"Gesamter Massenfluss der Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['v_in_air'],
              xlabel="Zeit [s]", ylabel="Geschwindigkeit [m/s]",
              title=f"Geschwindigkeit der Luft am inlet", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_air_mean'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Gemittelte Austrittstemperatur Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_ref'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Austrittstemperatur Kältemittel", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_evap'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Verdampferseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_cond'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Kondenserseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['humidity'],
              xlabel="Zeit [s]", ylabel="Feuchtegehalt [kg/kg]",
              title=f"Feuchtgehalt entlang dem Luftstrom", marker=None,
              labels=["Seg 1","Seg 2","Seg 3","Seg 4","Seg 5"])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Feuchtgehalt entlang dem Luftstrom'}, xlabel='Zeit [s]', ylabel='Feuchtegehalt [kg/kg]'>)

# %%
# Segment auswählen
ix, iy = 0, 2

plot_r = int(gs.nr-1)
plot_x = int(gs.nx-1)
plot_theta = int(gs.ntheta-1)
plot_time = int(max(data['t'])/gs.dt)

t, s_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_e", ix, iy)
plot.plot_any(kind="time vs 1D(theta)",
              x=t, y=s_e,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Edge Frostdicke bei θ_idx = {plot_theta} – Segment ({ix},{iy})",
              theta_idx=plot_theta, marker=None)
t, s_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_ft", ix, iy)
plot.plot_any(kind="time vs any",
              x=t, y=s_ft,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"F&T Frostdicke – Segment ({ix},{iy})", marker=None)
t, T_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=T_e,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Edge Frosttemperatur bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, T_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=T_ft,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"F&T Frosttemperatur bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_e,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"Edge Frostdichte bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, rho_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=rho_ft,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"F&T Frostdichte bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_a_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_a_e,
              xlabel="Zeit [s]", ylabel="Dichte der trockenen Luft [kg/m^3]",
              title=f"Edge Dichte der trockenen Luft bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, w_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=w_e,
              xlabel="Zeit [s]", ylabel="w [kg/kg]",
              title=f"Edge Feuchtigkeit bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Edge Feuchtigkeit bei r_idx = 99 und θ_idx = 89 – Segment (0,2)'}, xlabel='Zeit [s]', ylabel='w [kg/kg]'>)

# %%
_, T_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e",      ix, iy)
plot.plot_spatial_slice(
    T_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, T_ft      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft",      ix, iy)
plot.plot_spatial_slice(
    T_ft, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_ft(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, rho_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e",      ix, iy)
plot.plot_spatial_slice(
    rho_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_e [kg/m^3]", marker=None
)
_, w_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e",      ix, iy)
plot.plot_spatial_slice(
    w_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"w_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="w_e [kg/kg]", marker=None
)
_, rho_a_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e",      ix, iy)
plot.plot_spatial_slice(
    rho_a_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_a(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_a [kg/m^3]", marker=None
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 _, T_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e",      ix, iy)
# ----> 2 plot.plot_spatial_slice(
#       3     T_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
#       4     title=f"T_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
#       5 )
#       6 _, T_ft      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft",      ix, iy)
#       7 plot.plot_spatial_slice(
#       8     T_ft, vary="r", t_idx=plot_time, theta_idx=plot_theta,
#       9     title=f"T_ft(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
#      10 )
#
# File ~\OneDrive\Dokumente\GitHub\MSE_VT1_luethluk\Framework\visualisation\plot.py:215, in plot_spatial_slice(y, vary, t_idx, r_idx, theta_idx, r_coords, theta_coords, title, xlabel, ylabel, save_path, show, marker, line_kwargs)
#     213     nt, nr, ntheta = y.shape
#     214     if not (0 <= t_idx < nt):
# --> 215         raise IndexError(f"t_idx {t_idx} out of bounds for time axis with size {nt}")
#     216     y_t = y[t_idx]
#     217 elif y.ndim == 2:
#
# IndexError: t_idx 45 out of bounds for time axis with size 5
