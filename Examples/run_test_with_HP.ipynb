# %%
from pathlib import Path
import sys
import numpy as np
from CoolProp.HumidAirProp import HAPropsSI
from CoolProp.CoolProp import PropsSI
sys.path.insert(0, str(Path.cwd().parent))
from Framework.core.config import CaseConfig, GridShape, HeatPump
from Framework.core.geometry import FinnTubedHX
from Framework.models import Frostmodell_V1
from Framework.runtime.simulator_V2 import Simulator
from Framework.visualisation import plot
from Framework.runtime.recorder import ResultRecorder

# %% [markdown]
# # Case Definieren

# %%
sim_run = True
read_data = True

#air
T_a = 10.0
P = 101325
RH = 0.1
v_a = 1.2

#water
T_in_water = 30.0
N_cond = 22

#refrigerant
w_amb_in = HAPropsSI('W','T',T_a+273.15,'P',P,'R', RH)
rho_amb_in = 1.0 / HAPropsSI("Vha","T",T_a+273.15,"P",P,"R",RH)

refrigerant = "R134a"
#at evaportor
x_evap = 0.5
p_ref_evap = PropsSI("P", "T", T_a + 273.15, "Q", x_evap, refrigerant)
h_ref_evap = PropsSI("H", "T", T_a + 273.15, "Q", x_evap, refrigerant)

#at condenser
x_cond = 0.5
p_ref_cond = PropsSI("P", "T", T_in_water + 273.15, "Q", x_cond, refrigerant)
h_ref_cond = PropsSI("H", "T", T_in_water + 273.15, "Q", x_cond, refrigerant)

geom = FinnTubedHX(
    n_seg_l = 2,        # -
    n_seg_r = 20,        # -
    stacks = 100,         # -
    n_fin = 2,           # -
    l_fin = 0.022,          # m
    h_fin = 0.022,          # m
    fin_thickness = 0.0002,    # m
    fin_pitch_cc = 0.0032,          # m
    d_tube_a = 0.00952,          # m
    tube_thickness = 0.0005,       # m
    lambda_fin = 237,            # W/mK
    rho_solid = 2700,            # kg/m3
    c_solid = 900,               # J/kgK
    CP = "row_serpentine"
)

gs = GridShape(
    t_end = 60.0,      # s endtime
    dt = 1.0,           # s time step
    store_grid_every_x_it = 10,

    nx = 100,
    nr = 100,
    ntheta = 90,

    #Model Setup
    cal_steady_state = False,
    cal_air = True,
    cal_frost = False,
    cal_ref = True
)

cfg = CaseConfig(
    # air data
    m_dot = v_a*rho_amb_in*(geom.h_fin*geom.fin_gap()*geom.n_seg_r*geom.stacks), # Backup massflow if no fan is used
    T_a = T_a,          # °C temperature air
    v_a = v_a,          # m/s velocity air
    p_a = P,            # Pa pressure air
    RH = RH,            # relative humidity air
    w_amb = w_amb_in,          # kg/kg water vapor moisture content
    rho_amb = rho_amb_in,      # kg/m^3 density air
    v_kin = 1.5e-5,     # m^2/s kinematic viscosity air
    lam = 0.025,        # W/mK heat conduction coefficient air
    c_p_a = 1000,       # J/kgK heat capacity air
    D_std = 2.2e-5,     # m^2/s water vapor diffusion coefficient
    C = 900,            # 1/s empirical water vapor absorbed coefficient
    isv = 2830000,      # J/kg latent heat of desublimation

    # fan model
    use_fan = True,
    fan_dp0 = 150.0,
    fan_V0 = v_a*(geom.h_fin*geom.fin_gap()*geom.n_seg_r*geom.stacks),
    dp_clean = 40.0,


    # refrigerant data
    ref_str = refrigerant,
    T_tube = T_a,    # °C tube temperature
    T_ref = T_a,     # °C tube temperature
    p_ref = p_ref_evap,      # Pa Kältemitteldruck
    h_ref = h_ref_evap,          # J/kg spezifische Enthalpie
    m_dot_ref = 0,      # kg/s Massenstrom am Inlet (invalid)
    m_dot_ref_out = 0,      # kg/s Massenstrom am Outlet (invalid)
    x_ref = x_evap,           # Dampfqualität (0..1), NaN falls einphasig

    # ice data
    rho_i = 920,        # kg/m^3 ice density
    h_sub= 2830000,     # J/kg latent heat of ablimation for water vapor
)

HP = HeatPump(
    N_cond=N_cond,
    p_ref_cond = p_ref_cond,
    h_ref_cond = np.full(N_cond, h_ref_cond, dtype=float),
    T_wall = np.full(N_cond, T_in_water, dtype=float),
    T_water = np.full(N_cond, T_in_water, dtype=float),

    A_flow_cond = 0.01,
    dx_cond = 0.5/N_cond,
    t_plate = 0.001,
    height_cond=1.0,
    A_plate = 3.65,
    c_plate = 500,
    rho_plate = 8000.0,
    lamda_plate = 50.0,

    #water
    T_in_water = T_in_water,
    m_water = 0.5,
    c_water = 4200,
    rho_water = 997
)

plot.plot_finned_tube_side(geom)
print(f"Surface area Evaporator = {geom.A_one_segment()*geom.n_seg_r*geom.n_seg_l*geom.stacks:.2f} m2")
print(f"Surface area Condenser = {HP.A_plate:.2f} m2")
# Out:
# Surface area Evaporator = 3.66 m2
# Surface area Condenser = 3.65 m2

# %% [markdown]
# # Simulation laufen lassen

# %%
result_file = "results_test"

if sim_run:
    sim = Simulator(geom,cfg,HP,result_file)
    results = sim.run(cfg, geom, gs, Frostmodell_V1)
# Out:
# Time Step: 1	 Time: 0.0 s | 0.0 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=62, evap_out=TP(x=0.517, Tsat=10.01°C, T=10.01°C), cond_out=TP(x=0.507, Tsat=30.05°C, T=30.05°C), Q_evap=921.69 W, Q_cond=346.08 W, ct=1.874 s)
# Cycle time for time step 1: 2.5 s
# Time remaining: 2.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 2	 Time: 1.0 s | 0.0 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=167, evap_out=TP(x=0.967, Tsat=4.82°C, T=4.82°C), cond_out=TP(x=0.538, Tsat=30.33°C, T=30.33°C), Q_evap=1966.01 W, Q_cond=2172.48 W, ct=21.623 s)
# Cycle time for time step 2: 21.8 s
# Time remaining: 21.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 3	 Time: 2.0 s | 0.0 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.71 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=8.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=8.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=8.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=8.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=8.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=8.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=8.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=8.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=8.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=234, evap_out=SH=16.40K (Tsat=-10.04°C, T=6.36°C), cond_out=TP(x=0.696, Tsat=30.33°C, T=30.33°C), Q_evap=753.43 W, Q_cond=2058.62 W, ct=36.652 s)
# Cycle time for time step 3: 36.8 s
# Time remaining: 35.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 4	 Time: 3.0 s | 0.1 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=8.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.15 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.15 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=8.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=70, evap_out=SH=24.49K (Tsat=-16.58°C, T=7.91°C), cond_out=TP(x=0.656, Tsat=30.32°C, T=30.32°C), Q_evap=906.26 W, Q_cond=1831.56 W, ct=6.396 s)
# Cycle time for time step 4: 6.6 s
# Time remaining: 6.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 5	 Time: 4.0 s | 0.1 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.24 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.31 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.34 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.34 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.31 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.24 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=62, evap_out=SH=28.84K (Tsat=-20.27°C, T=8.57°C), cond_out=TP(x=0.633, Tsat=30.36°C, T=30.36°C), Q_evap=1016.63 W, Q_cond=2014.60 W, ct=11.498 s)
# Cycle time for time step 5: 11.7 s
# Time remaining: 10.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 6	 Time: 5.0 s | 0.1 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.26 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.31 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.39 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.41 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.44 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.47 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.49 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.49 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.47 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=54, evap_out=SH=32.03K (Tsat=-23.05°C, T=8.97°C), cond_out=TP(x=0.614, Tsat=30.39°C, T=30.39°C), Q_evap=1100.88 W, Q_cond=2204.90 W, ct=7.757 s)
# Cycle time for time step 6: 8.0 s
# Time remaining: 7.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 7	 Time: 6.0 s | 0.1 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.24 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.31 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.37 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.42 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.55 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.57 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=38, evap_out=SH=34.53K (Tsat=-25.28°C, T=9.25°C), cond_out=TP(x=0.598, Tsat=30.42°C, T=30.42°C), Q_evap=1178.91 W, Q_cond=2378.82 W, ct=3.164 s)
# Cycle time for time step 7: 3.4 s
# Time remaining: 3.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 8	 Time: 7.0 s | 0.1 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.36 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.41 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.54 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.65 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.68 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.69 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.71 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.71 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.71 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.71 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=38, evap_out=SH=36.57K (Tsat=-27.12°C, T=9.44°C), cond_out=TP(x=0.585, Tsat=30.45°C, T=30.45°C), Q_evap=1244.90 W, Q_cond=2537.35 W, ct=5.115 s)
# Cycle time for time step 8: 5.3 s
# Time remaining: 4.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 9	 Time: 8.0 s | 0.1 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.45 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.54 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.64 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.69 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.71 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=31, evap_out=SH=38.27K (Tsat=-28.69°C, T=9.58°C), cond_out=TP(x=0.573, Tsat=30.48°C, T=30.48°C), Q_evap=1310.54 W, Q_cond=2682.72 W, ct=2.258 s)
# Cycle time for time step 9: 2.4 s
# Time remaining: 2.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 10	 Time: 9.0 s | 0.1 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.56 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.64 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=25, evap_out=SH=39.73K (Tsat=-30.04°C, T=9.69°C), cond_out=TP(x=0.562, Tsat=30.51°C, T=30.51°C), Q_evap=1367.07 W, Q_cond=2817.93 W, ct=3.836 s)
# Cycle time for time step 10: 4.7 s
# Time remaining: 4.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 11	 Time: 10.0 s | 0.2 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.55 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.65 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.68 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.71 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=34, evap_out=SH=40.98K (Tsat=-31.23°C, T=9.76°C), cond_out=TP(x=0.552, Tsat=30.54°C, T=30.54°C), Q_evap=1420.86 W, Q_cond=2945.20 W, ct=3.115 s)
# Cycle time for time step 11: 3.4 s
# Time remaining: 2.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 12	 Time: 11.0 s | 0.2 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.54 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.71 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=23, evap_out=SH=42.09K (Tsat=-32.28°C, T=9.81°C), cond_out=TP(x=0.542, Tsat=30.57°C, T=30.57°C), Q_evap=1486.89 W, Q_cond=3064.28 W, ct=3.695 s)
# Cycle time for time step 12: 3.9 s
# Time remaining: 3.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 13	 Time: 12.0 s | 0.2 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.59 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=34, evap_out=SH=43.09K (Tsat=-33.23°C, T=9.85°C), cond_out=TP(x=0.533, Tsat=30.60°C, T=30.60°C), Q_evap=1520.28 W, Q_cond=3176.06 W, ct=5.471 s)
# Cycle time for time step 13: 5.7 s
# Time remaining: 4.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 14	 Time: 13.0 s | 0.2 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.41 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.54 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=33, evap_out=SH=43.97K (Tsat=-34.09°C, T=9.88°C), cond_out=TP(x=0.524, Tsat=30.63°C, T=30.63°C), Q_evap=1563.54 W, Q_cond=3282.02 W, ct=5.586 s)
# Cycle time for time step 14: 5.8 s
# Time remaining: 4.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 15	 Time: 14.0 s | 0.2 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.31 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.66 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=20, evap_out=SH=44.78K (Tsat=-34.87°C, T=9.91°C), cond_out=TP(x=0.514, Tsat=30.65°C, T=30.65°C), Q_evap=1605.58 W, Q_cond=3384.16 W, ct=1.382 s)
# Cycle time for time step 15: 1.6 s
# Time remaining: 1.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 16	 Time: 15.0 s | 0.2 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.37 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.69 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=37, evap_out=SH=44.77K (Tsat=-34.82°C, T=9.95°C), cond_out=TP(x=0.505, Tsat=30.68°C, T=30.68°C), Q_evap=1669.93 W, Q_cond=3435.34 W, ct=4.450 s)
# Cycle time for time step 16: 4.6 s
# Time remaining: 3.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 17	 Time: 16.0 s | 0.3 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.43 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# ...
# Seg[1,0] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=30, evap_out=TP(x=0.855, Tsat=-28.25°C, T=-28.25°C), cond_out=TP(x=0.090, Tsat=32.13°C, T=32.13°C), Q_evap=3915.84 W, Q_cond=5827.46 W, ct=1.126 s)
# Cycle time for time step 28: 1.3 s
# Time remaining: 0.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 29	 Time: 28.0 s | 0.5 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=47, evap_out=TP(x=0.932, Tsat=-28.60°C, T=-28.60°C), cond_out=TP(x=0.123, Tsat=32.22°C, T=32.22°C), Q_evap=3942.88 W, Q_cond=5931.58 W, ct=5.651 s)
# Cycle time for time step 29: 5.8 s
# Time remaining: 3.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 30	 Time: 29.0 s | 0.5 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=110, evap_out=SH=2.22K (Tsat=-29.13°C, T=-26.90°C), cond_out=TP(x=0.171, Tsat=32.21°C, T=32.21°C), Q_evap=3805.22 W, Q_cond=6100.57 W, ct=15.941 s)
# Cycle time for time step 30: 16.7 s
# Time remaining: 8.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 31	 Time: 30.0 s | 0.5 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-3.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-3.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-3.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-2.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-2.65 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-2.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=184, evap_out=SH=12.10K (Tsat=-30.86°C, T=-18.76°C), cond_out=TP(x=0.245, Tsat=32.12°C, T=32.12°C), Q_evap=3080.30 W, Q_cond=5594.11 W, ct=34.745 s)
# Cycle time for time step 31: 34.9 s
# Time remaining: 17.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 32	 Time: 31.0 s | 0.5 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-3.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-3.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-3.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-3.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-3.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-3.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-3.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-3.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-2.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-2.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-1.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-1.47 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-1.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-0.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-0.56 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-0.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-0.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=0.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=0.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-0.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=205, evap_out=SH=20.88K (Tsat=-32.96°C, T=-12.08°C), cond_out=TP(x=0.368, Tsat=31.97°C, T=31.97°C), Q_evap=2190.62 W, Q_cond=4853.29 W, ct=41.928 s)
# Cycle time for time step 32: 42.1 s
# Time remaining: 20.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 33	 Time: 32.0 s | 0.5 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-2.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-2.44 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-2.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-1.68 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-1.36 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-1.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-0.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-0.41 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-0.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=0.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=0.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=0.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=1.26 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=1.53 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=1.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=2.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=2.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=2.40 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=2.56 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=2.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...

# %% [markdown]
# # Resultate speichen/laden

# %%
if sim_run:
    data = results.data
    results.to_csv(result_file,data)

if read_data:
    data = ResultRecorder.read_results_csv_json(result_file)
    results = ResultRecorder.from_jsonl(result_file)

# %% [markdown]
# # Resultate plotten

# %%
snapshots = results.grid_snapshots

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="v_a",
    source="cfg",
    t_idx=-1,          # letzter Zeitschritt
    title="Geschwindigkeit der Luft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="s_ft",
    source="st",       # aus SimState
    t_idx=-1,          # letzter Zeitschritt
    title="Frostdicke s_ft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_a",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Lufttemperatur T_a über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="w_amb",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="RH",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="relative Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_tube",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur der Wände über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur des Kältemittels über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="h_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Enthalpie des Kältemittels über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="p_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Druck vom Kältemittel über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="x_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="X des Kältemittel über alle Segmente",
    cmap="viridis"
)

# %%
plot.plot_logph_cycles(
    ref=cfg.ref_str,
    t=data["t"],
    cycle_ph=data["cycle_ph"],
    at_time=gs.t_end,
    isotherms=True,
)

plot.plot_logph_cycles(
    ref=cfg.ref_str,
    t=data["t"],
    cycle_ph=data["cycle_ph"],
    t_start=60.0,
    t_end=gs.t_end,
    every_s=60.0,   # alle 60 s ein Kreisprozess
    isotherms=True,
    title="Kreisprozess über die Zeit"
)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['EER'],
              xlabel="Zeit [s]", ylabel="EER",
              title=f"EER", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['COP'],
              xlabel="Zeit [s]", ylabel="COP",
              title=f"COP", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['mean_s_ft'],
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Durchschnittliche Frostdicke", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['m_dot_air'],
              xlabel="Zeit [s]", ylabel="Massenfluss [kg/s]",
              title=f"Gesamter Massenfluss der Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['v_in_air'],
              xlabel="Zeit [s]", ylabel="Geschwindigkeit [m/s]",
              title=f"Geschwindigkeit der Luft am inlet", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_air_mean'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Gemittelte Austrittstemperatur Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_ref'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Austrittstemperatur Kältemittel", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_evap'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Verdampferseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_cond'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Kondenserseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['humidity'],
              xlabel="Zeit [s]", ylabel="Feuchtegehalt [kg/kg]",
              title=f"Feuchtgehalt entlang dem Luftstrom", marker=None,
              labels=["Seg 1","Seg 2","Seg 3","Seg 4","Seg 5"])

# %%
# Segment auswählen
ix, iy = 0, 2

plot_r = int(gs.nr-1)
plot_x = int(gs.nx-1)
plot_theta = int(gs.ntheta-1)
plot_time = int(max(data['t'])/gs.dt)

t, s_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_e", ix, iy)
plot.plot_any(kind="time vs 1D(theta)",
              x=t, y=s_e,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Edge Frostdicke bei θ_idx = {plot_theta} – Segment ({ix},{iy})",
              theta_idx=plot_theta, marker=None)
t, s_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_ft", ix, iy)
plot.plot_any(kind="time vs any",
              x=t, y=s_ft,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"F&T Frostdicke – Segment ({ix},{iy})", marker=None)
t, T_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=T_e,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Edge Frosttemperatur bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, T_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=T_ft,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"F&T Frosttemperatur bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_e,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"Edge Frostdichte bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, rho_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=rho_ft,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"F&T Frostdichte bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_a_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_a_e,
              xlabel="Zeit [s]", ylabel="Dichte der trockenen Luft [kg/m^3]",
              title=f"Edge Dichte der trockenen Luft bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, w_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=w_e,
              xlabel="Zeit [s]", ylabel="w [kg/kg]",
              title=f"Edge Feuchtigkeit bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)

# %%
_, T_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e",      ix, iy)
plot.plot_spatial_slice(
    T_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, T_ft      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft",      ix, iy)
plot.plot_spatial_slice(
    T_ft, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_ft(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, rho_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e",      ix, iy)
plot.plot_spatial_slice(
    rho_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_e [kg/m^3]", marker=None
)
_, w_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e",      ix, iy)
plot.plot_spatial_slice(
    w_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"w_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="w_e [kg/kg]", marker=None
)
_, rho_a_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e",      ix, iy)
plot.plot_spatial_slice(
    rho_a_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_a(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_a [kg/m^3]", marker=None
)
