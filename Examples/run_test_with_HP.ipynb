# %%
from pathlib import Path
import sys
import numpy as np
from CoolProp.HumidAirProp import HAPropsSI
from CoolProp.CoolProp import PropsSI
sys.path.insert(0, str(Path.cwd().parent))
from Framework.core.config import CaseConfig, GridShape, HeatPump
from Framework.core.geometry import FinnTubedHX
from Framework.models import Frostmodell_V1
from Framework.runtime.simulator_V2 import Simulator
from Framework.visualisation import plot
from Framework.runtime.recorder import ResultRecorder

# %% [markdown]
# # Case Definieren

# %%
sim_run = True
read_data = True

#air
T_a = 10.0
P = 101325
RH = 0.1
v_a = 1.2

#water
T_in_water = 30.0
N_cond = 22

#refrigerant
w_amb_in = HAPropsSI('W','T',T_a+273.15,'P',P,'R', RH)
rho_amb_in = 1.0 / HAPropsSI("Vha","T",T_a+273.15,"P",P,"R",RH)

refrigerant = "R134a"
#at evaportor
x_evap = 0.5
p_ref_evap = PropsSI("P", "T", T_a + 273.15, "Q", x_evap, refrigerant)
h_ref_evap = PropsSI("H", "T", T_a + 273.15, "Q", x_evap, refrigerant)

#at condenser
x_cond = 0.5
p_ref_cond = PropsSI("P", "T", T_in_water + 273.15, "Q", x_cond, refrigerant)
h_ref_cond = PropsSI("H", "T", T_in_water + 273.15, "Q", x_cond, refrigerant)

geom = FinnTubedHX(
    n_seg_l = 2,        # -
    n_seg_r = 20,        # -
    stacks = 150,         # -
    n_fin = 2,           # -
    l_fin = 0.022,          # m
    h_fin = 0.022,          # m
    fin_thickness = 0.0002,    # m
    fin_pitch_cc = 0.0032,          # m
    d_tube_a = 0.00952,          # m
    tube_thickness = 0.0005,       # m
    lambda_fin = 237,            # W/mK
    rho_solid = 2700,            # kg/m3
    c_solid = 900,               # J/kgK
    CP = "row_serpentine"
)

gs = GridShape(
    t_end = 60.0,      # s endtime
    dt = 1.0,           # s time step
    store_grid_every_x_it = 10,

    nx = 100,
    nr = 100,
    ntheta = 90,

    #Model Setup
    cal_steady_state = False,
    cal_air = True,
    cal_frost = False,
    cal_ref = True
)

cfg = CaseConfig(
    # air data
    m_dot = v_a*rho_amb_in*(geom.h_fin*geom.fin_gap()*geom.n_seg_r*geom.stacks), # Backup massflow if no fan is used
    T_a = T_a,          # °C temperature air
    v_a = v_a,          # m/s velocity air
    p_a = P,            # Pa pressure air
    RH = RH,            # relative humidity air
    w_amb = w_amb_in,          # kg/kg water vapor moisture content
    rho_amb = rho_amb_in,      # kg/m^3 density air
    v_kin = 1.5e-5,     # m^2/s kinematic viscosity air
    lam = 0.025,        # W/mK heat conduction coefficient air
    c_p_a = 1000,       # J/kgK heat capacity air
    D_std = 2.2e-5,     # m^2/s water vapor diffusion coefficient
    C = 900,            # 1/s empirical water vapor absorbed coefficient
    isv = 2830000,      # J/kg latent heat of desublimation

    # fan model
    use_fan = True,
    fan_dp0 = 150.0,
    fan_V0 = v_a*(geom.h_fin*geom.fin_gap()*geom.n_seg_r*geom.stacks),
    dp_clean = 40.0,


    # refrigerant data
    ref_str = refrigerant,
    T_tube = T_a,    # °C tube temperature
    T_ref = T_a,     # °C tube temperature
    p_ref = p_ref_evap,      # Pa Kältemitteldruck
    h_ref = h_ref_evap,          # J/kg spezifische Enthalpie
    m_dot_ref = 0,      # kg/s Massenstrom am Inlet (invalid)
    m_dot_ref_out = 0,      # kg/s Massenstrom am Outlet (invalid)
    x_ref = x_evap,           # Dampfqualität (0..1), NaN falls einphasig

    # ice data
    rho_i = 920,        # kg/m^3 ice density
    h_sub= 2830000,     # J/kg latent heat of ablimation for water vapor
)

HP = HeatPump(
    N_cond=N_cond,
    p_ref_cond = p_ref_cond,
    h_ref_cond = np.full(N_cond, h_ref_cond, dtype=float),
    T_wall = np.full(N_cond, T_in_water, dtype=float),
    T_water = np.full(N_cond, T_in_water, dtype=float),

    A_flow_cond = 0.01,
    dx_cond = 0.5/N_cond,
    t_plate = 0.001,
    height_cond=1.0,
    A_plate = 3.65,
    c_plate = 500,
    rho_plate = 8000.0,
    lamda_plate = 50.0,

    #water
    T_in_water = T_in_water,
    m_water = 0.5,
    c_water = 4200,
    rho_water = 997
)

plot.plot_finned_tube_side(geom)
print(f"Surface area Evaporator = {geom.A_one_segment()*geom.n_seg_r*geom.n_seg_l*geom.stacks:.2f} m2")
print(f"Surface area Condenser = {HP.A_plate:.2f} m2")
# Out:
# Surface area Evaporator = 5.49 m2
# Surface area Condenser = 3.65 m2

# %% [markdown]
# # Simulation laufen lassen

# %%
result_file = "results_test"

if sim_run:
    sim = Simulator(geom,cfg,HP,result_file)
    results = sim.run(cfg, geom, gs, Frostmodell_V1)
# Out:
# Time Step: 1	 Time: 0.0 s | 0.0 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=53, evap_out=TP(x=0.511, Tsat=10.03°C, T=10.03°C), cond_out=TP(x=0.506, Tsat=30.05°C, T=30.05°C), Q_evap=916.97 W, Q_cond=340.49 W, ct=2.187 s)
# Cycle time for time step 1: 2.8 s
# Time remaining: 2.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 2	 Time: 1.0 s | 0.0 min
# Seg[0,0] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=45, evap_out=TP(x=0.813, Tsat=6.84°C, T=6.84°C), cond_out=TP(x=0.502, Tsat=30.34°C, T=30.34°C), Q_evap=2765.51 W, Q_cond=2226.16 W, ct=6.394 s)
# Cycle time for time step 2: 6.6 s
# Time remaining: 6.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 3	 Time: 2.0 s | 0.0 min
# Seg[0,0] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=8.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=339, evap_out=SH=11.29K (Tsat=-5.99°C, T=5.30°C), cond_out=TP(x=0.748, Tsat=30.46°C, T=30.46°C), Q_evap=688.59 W, Q_cond=2781.79 W, ct=87.813 s)
# Cycle time for time step 3: 88.3 s
# Time remaining: 85.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 4	 Time: 3.0 s | 0.1 min
# Seg[0,0] | Air(T=8.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=8.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=8.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=8.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=8.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=8.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=8.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=8.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=8.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=8.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=8.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=8.68 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=8.66 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=8.65 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=8.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.15 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=8.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=8.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=7.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=7.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=7.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=7.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=7.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=7.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=7.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=7.39 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=7.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=7.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=7.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=6.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=6.59 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=6.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=5.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=4.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=44, evap_out=SH=22.98K (Tsat=-15.88°C, T=7.10°C), cond_out=TP(x=0.680, Tsat=30.39°C, T=30.39°C), Q_evap=835.34 W, Q_cond=2025.04 W, ct=7.884 s)
# Cycle time for time step 4: 8.2 s
# Time remaining: 7.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 5	 Time: 4.0 s | 0.1 min
# Seg[0,0] | Air(T=9.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.23 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.24 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.23 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=8.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.34 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=8.36 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=8.36 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=8.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=7.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=7.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=7.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=7.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=7.47 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=7.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=6.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=5.31 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=2.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=0.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=53, evap_out=SH=28.08K (Tsat=-20.00°C, T=8.07°C), cond_out=TP(x=0.637, Tsat=30.41°C, T=30.41°C), Q_evap=998.81 W, Q_cond=2074.93 W, ct=12.355 s)
# Cycle time for time step 5: 12.9 s
# Time remaining: 12.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 6	 Time: 5.0 s | 0.1 min
# Seg[0,0] | Air(T=9.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.39 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.42 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.43 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.44 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.43 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.43 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.41 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.40 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.38 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.36 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.34 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.31 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.26 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=8.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=8.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=8.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.55 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.40 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=8.34 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=8.26 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=8.15 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=7.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=7.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=6.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=5.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=1.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-0.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-0.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=53, evap_out=SH=31.50K (Tsat=-22.84°C, T=8.66°C), cond_out=TP(x=0.614, Tsat=30.44°C, T=30.44°C), Q_evap=1102.23 W, Q_cond=2262.73 W, ct=12.475 s)
# Cycle time for time step 6: 12.8 s
# Time remaining: 11.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 7	 Time: 6.0 s | 0.1 min
# Seg[0,0] | Air(T=9.31 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.40 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.55 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.57 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.57 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.56 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.54 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.53 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.49 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.47 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.49 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=8.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=8.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=8.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=8.64 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=8.53 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=8.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=7.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=7.11 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=5.49 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=2.37 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-1.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-1.47 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-1.47 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=35, evap_out=SH=34.14K (Tsat=-25.10°C, T=9.04°C), cond_out=TP(x=0.598, Tsat=30.47°C, T=30.47°C), Q_evap=1183.12 W, Q_cond=2434.49 W, ct=5.687 s)
# Cycle time for time step 7: 5.9 s
# Time remaining: 5.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 8	 Time: 7.0 s | 0.1 min
# Seg[0,0] | Air(T=9.42 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.49 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.55 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.64 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.66 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.68 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.69 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.69 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.69 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.69 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.68 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.66 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.65 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.64 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=8.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=8.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=7.41 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=5.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=3.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-0.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-2.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-2.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-2.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=30, evap_out=SH=36.31K (Tsat=-27.00°C, T=9.31°C), cond_out=TP(x=0.586, Tsat=30.50°C, T=30.50°C), Q_evap=1243.49 W, Q_cond=2583.23 W, ct=4.912 s)
# Cycle time for time step 8: 5.2 s
# Time remaining: 4.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 9	 Time: 8.0 s | 0.1 min
# Seg[0,0] | Air(T=9.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.57 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.15 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.22 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.24 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.23 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=8.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=8.43 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=7.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=6.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=4.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=2.15 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-1.41 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-2.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-2.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-2.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=29, evap_out=SH=38.13K (Tsat=-28.62°C, T=9.51°C), cond_out=TP(x=0.577, Tsat=30.52°C, T=30.52°C), Q_evap=1299.62 W, Q_cond=2714.80 W, ct=5.625 s)
# Cycle time for time step 9: 6.0 s
# Time remaining: 5.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 10	 Time: 9.0 s | 0.1 min
# Seg[0,0] | Air(T=9.59 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.64 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.68 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.37 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.38 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.37 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=8.65 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=8.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=7.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=5.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=3.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=1.23 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-2.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-3.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-3.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-3.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=26, evap_out=SH=39.67K (Tsat=-30.02°C, T=9.65°C), cond_out=TP(x=0.568, Tsat=30.55°C, T=30.55°C), Q_evap=1340.39 W, Q_cond=2834.98 W, ct=0.429 s)
# Cycle time for time step 10: 1.4 s
# Time remaining: 1.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 11	 Time: 10.0 s | 0.2 min
# Seg[0,0] | Air(T=9.66 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.42 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.45 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.47 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.41 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.31 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=8.39 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=7.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=6.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=5.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=3.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=0.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-2.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-3.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-3.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-3.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=29, evap_out=SH=41.00K (Tsat=-31.25°C, T=9.75°C), cond_out=TP(x=0.560, Tsat=30.57°C, T=30.57°C), Q_evap=1385.03 W, Q_cond=2946.00 W, ct=5.296 s)
# Cycle time for time step 11: 5.5 s
# Time remaining: 4.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 12	 Time: 11.0 s | 0.2 min
# Seg[0,0] | Air(T=9.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.54 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.55 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.55 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.54 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.41 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.65 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=8.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=7.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=6.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=4.68 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=2.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=0.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-3.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-4.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-4.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-4.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=22, evap_out=SH=42.17K (Tsat=-32.35°C, T=9.82°C), cond_out=TP(x=0.553, Tsat=30.59°C, T=30.59°C), Q_evap=1417.00 W, Q_cond=3047.94 W, ct=2.073 s)
# Cycle time for time step 12: 2.6 s
# Time remaining: 2.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 13	 Time: 12.0 s | 0.2 min
# Seg[0,0] | Air(T=9.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.57 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.49 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.37 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.43 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=7.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=6.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=5.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=4.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=2.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-0.24 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-3.69 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-4.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-4.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-4.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=24, evap_out=SH=43.22K (Tsat=-33.34°C, T=9.87°C), cond_out=TP(x=0.547, Tsat=30.61°C, T=30.61°C), Q_evap=1460.73 W, Q_cond=3141.21 W, ct=4.794 s)
# Cycle time for time step 13: 5.1 s
# Time remaining: 4.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 14	 Time: 13.0 s | 0.2 min
# Seg[0,0] | Air(T=9.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.66 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.66 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.65 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.56 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.23 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=7.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=6.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=5.55 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=4.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=2.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-0.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-4.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-4.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-4.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-4.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=26, evap_out=SH=44.16K (Tsat=-34.25°C, T=9.91°C), cond_out=TP(x=0.541, Tsat=30.63°C, T=30.63°C), Q_evap=1483.63 W, Q_cond=3226.71 W, ct=0.736 s)
# Cycle time for time step 14: 1.0 s
# Time remaining: 0.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 15	 Time: 14.0 s | 0.2 min
# Seg[0,0] | Air(T=9.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.69 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.54 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.41 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.22 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.57 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=7.39 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=6.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=5.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=3.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=1.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-0.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-4.39 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-5.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-5.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-5.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=20, evap_out=SH=45.02K (Tsat=-35.08°C, T=9.93°C), cond_out=TP(x=0.536, Tsat=30.65°C, T=30.65°C), Q_evap=1511.27 W, Q_cond=3306.12 W, ct=2.699 s)
# Cycle time for time step 15: 2.9 s
# Time remaining: 2.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 16	 Time: 15.0 s | 0.2 min
# Seg[0,0] | Air(T=9.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.45 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=7.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=7.23 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=6.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=5.15 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=3.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=1.56 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-1.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-4.68 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-5.43 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-5.43 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-5.43 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=28, evap_out=SH=45.09K (Tsat=-35.12°C, T=9.97°C), cond_out=TP(x=0.531, Tsat=30.67°C, T=30.67°C), Q_evap=1551.88 W, Q_cond=3325.43 W, ct=7.644 s)
# Cycle time for time step 16: 8.1 s
# Time remaining: 6.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 17	 Time: 16.0 s | 0.3 min
# Seg[0,0] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.66 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# ...
# Seg[0,18] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.64 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.34 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.15 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.55 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=7.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=6.71 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=5.65 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=4.22 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=2.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-0.38 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-4.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-5.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-5.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-5.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-5.31 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=31, evap_out=SH=44.66K (Tsat=-34.62°C, T=10.04°C), cond_out=TP(x=0.488, Tsat=30.75°C, T=30.75°C), Q_evap=1773.53 W, Q_cond=3561.60 W, ct=5.169 s)
# Cycle time for time step 20: 6.2 s
# Time remaining: 4.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 21	 Time: 20.0 s | 0.3 min
# Seg[0,0] | Air(T=9.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.64 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.55 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.44 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.47 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=7.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=7.36 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=6.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=5.34 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=3.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=1.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-1.36 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-5.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-5.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-5.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-5.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-5.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=74, evap_out=SH=43.69K (Tsat=-33.73°C, T=9.97°C), cond_out=TP(x=0.438, Tsat=30.80°C, T=30.80°C), Q_evap=2063.57 W, Q_cond=3868.77 W, ct=19.225 s)
# Cycle time for time step 21: 19.4 s
# Time remaining: 13.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 22	 Time: 21.0 s | 0.3 min
# Seg[0,0] | Air(T=9.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.40 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=7.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=7.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=6.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=4.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=2.66 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-0.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-4.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-4.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-4.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-4.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-4.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-4.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=136, evap_out=SH=44.56K (Tsat=-33.71°C, T=10.85°C), cond_out=TP(x=0.386, Tsat=30.82°C, T=30.82°C), Q_evap=2239.31 W, Q_cond=3779.67 W, ct=29.692 s)
# Cycle time for time step 22: 29.9 s
# Time remaining: 19.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 23	 Time: 22.0 s | 0.4 min
# Seg[0,0] | Air(T=9.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.54 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.47 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.64 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=7.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=6.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=5.57 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=3.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=1.56 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-1.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-4.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-5.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-5.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-5.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-5.10 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-4.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=183, evap_out=SH=42.24K (Tsat=-33.38°C, T=8.86°C), cond_out=TP(x=0.502, Tsat=30.91°C, T=30.91°C), Q_evap=1819.00 W, Q_cond=4480.91 W, ct=32.274 s)
# Cycle time for time step 23: 32.5 s
# Time remaining: 20.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 24	 Time: 23.0 s | 0.4 min
# Seg[0,0] | Air(T=9.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.40 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.26 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.39 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=7.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=6.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=5.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=2.43 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-2.43 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-4.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-4.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-4.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-4.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-4.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-4.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-4.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-4.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=235, evap_out=SH=45.74K (Tsat=-32.58°C, T=13.16°C), cond_out=TP(x=0.271, Tsat=30.89°C, T=30.89°C), Q_evap=2904.37 W, Q_cond=3840.07 W, ct=43.312 s)
# Cycle time for time step 24: 44.0 s
# Time remaining: 27.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 25	 Time: 24.0 s | 0.4 min
# Seg[0,0] | Air(T=9.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.44 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=8.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=7.19 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=5.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=4.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=1.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=0.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-0.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-1.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-2.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-3.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-4.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-4.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-4.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-4.64 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...

# %% [markdown]
# # Resultate speichen/laden

# %%
if sim_run:
    data = results.data
    results.to_csv(result_file,data)

if read_data:
    data = ResultRecorder.read_results_csv_json(result_file)
    results = ResultRecorder.from_jsonl(result_file)

# %% [markdown]
# # Resultate plotten

# %%
snapshots = results.grid_snapshots

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="v_a",
    source="cfg",
    t_idx=-1,          # letzter Zeitschritt
    title="Geschwindigkeit der Luft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="s_ft",
    source="st",       # aus SimState
    t_idx=-1,          # letzter Zeitschritt
    title="Frostdicke s_ft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_a",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Lufttemperatur T_a über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="w_amb",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="RH",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="relative Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_tube",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur der Wände über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur des Kältemittels über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="h_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Enthalpie des Kältemittels über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="p_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Druck vom Kältemittel über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="x_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="X des Kältemittel über alle Segmente",
    cmap="viridis"
)

# %%
plot.plot_logph_cycles(
    ref=cfg.ref_str,
    t=data["t"],
    cycle_ph=data["cycle_ph"],
    at_time=gs.t_end,
    isotherms=True,
)

plot.plot_logph_cycles(
    ref=cfg.ref_str,
    t=data["t"],
    cycle_ph=data["cycle_ph"],
    t_start=60.0,
    t_end=gs.t_end,
    every_s=60.0,   # alle 60 s ein Kreisprozess
    isotherms=True,
    title="Kreisprozess über die Zeit"
)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['EER'],
              xlabel="Zeit [s]", ylabel="EER",
              title=f"EER", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['COP'],
              xlabel="Zeit [s]", ylabel="COP",
              title=f"COP", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['mean_s_ft'],
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Durchschnittliche Frostdicke", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['m_dot_air'],
              xlabel="Zeit [s]", ylabel="Massenfluss [kg/s]",
              title=f"Gesamter Massenfluss der Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['v_in_air'],
              xlabel="Zeit [s]", ylabel="Geschwindigkeit [m/s]",
              title=f"Geschwindigkeit der Luft am inlet", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_air_mean'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Gemittelte Austrittstemperatur Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_ref'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Austrittstemperatur Kältemittel", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_evap'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Verdampferseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_cond'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Kondenserseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['humidity'],
              xlabel="Zeit [s]", ylabel="Feuchtegehalt [kg/kg]",
              title=f"Feuchtgehalt entlang dem Luftstrom", marker=None,
              labels=["Seg 1","Seg 2","Seg 3","Seg 4","Seg 5"])

# %%
# Segment auswählen
ix, iy = 0, 2

plot_r = int(gs.nr-1)
plot_x = int(gs.nx-1)
plot_theta = int(gs.ntheta-1)
plot_time = int(max(data['t'])/gs.dt)

t, s_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_e", ix, iy)
plot.plot_any(kind="time vs 1D(theta)",
              x=t, y=s_e,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Edge Frostdicke bei θ_idx = {plot_theta} – Segment ({ix},{iy})",
              theta_idx=plot_theta, marker=None)
t, s_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_ft", ix, iy)
plot.plot_any(kind="time vs any",
              x=t, y=s_ft,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"F&T Frostdicke – Segment ({ix},{iy})", marker=None)
t, T_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=T_e,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Edge Frosttemperatur bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, T_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=T_ft,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"F&T Frosttemperatur bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_e,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"Edge Frostdichte bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, rho_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=rho_ft,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"F&T Frostdichte bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_a_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_a_e,
              xlabel="Zeit [s]", ylabel="Dichte der trockenen Luft [kg/m^3]",
              title=f"Edge Dichte der trockenen Luft bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, w_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=w_e,
              xlabel="Zeit [s]", ylabel="w [kg/kg]",
              title=f"Edge Feuchtigkeit bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)

# %%
_, T_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e",      ix, iy)
plot.plot_spatial_slice(
    T_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, T_ft      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft",      ix, iy)
plot.plot_spatial_slice(
    T_ft, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_ft(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, rho_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e",      ix, iy)
plot.plot_spatial_slice(
    rho_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_e [kg/m^3]", marker=None
)
_, w_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e",      ix, iy)
plot.plot_spatial_slice(
    w_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"w_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="w_e [kg/kg]", marker=None
)
_, rho_a_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e",      ix, iy)
plot.plot_spatial_slice(
    rho_a_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_a(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_a [kg/m^3]", marker=None
)
