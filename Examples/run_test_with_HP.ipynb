# %%
from pathlib import Path
import sys
import numpy as np
from CoolProp.HumidAirProp import HAPropsSI
from CoolProp.CoolProp import PropsSI
sys.path.insert(0, str(Path.cwd().parent))
from Framework.core.config import CaseConfig, GridShape, HeatPump
from Framework.core.geometry import FinnTubedHX
from Framework.models import Frostmodell_V1
from Framework.runtime.simulator_V2 import Simulator
from Framework.visualisation import plot
from Framework.runtime.recorder import ResultRecorder

# %% [markdown]
# # Case Definieren

# %%
sim_run = True
read_data = True

#air
T_a = 20.0
P = 101325
RH = 0.5
v_a = 1.2

#refrigerant
w_amb_in = HAPropsSI('W','T',T_a+273.15,'P',P,'R', RH)
rho_amb_in = 1.0 / HAPropsSI("Vha","T",T_a+273.15,"P",P,"R",RH)

refrigerant = "R134a"
#at evaportor
x_in = 0.5
p_ref_in = PropsSI("P", "T", T_a + 273.15, "Q", x_in, refrigerant)
h_ref_in = PropsSI("H", "T", T_a + 273.15, "Q", x_in, refrigerant)

#water
T_in_water = 30.0
N_cond = 10

#at condenser
p_ref_cond = PropsSI("P", "T", T_in_water + 273.15, "Q", x_in, refrigerant)
h_ref_cond = PropsSI("H", "T", T_in_water + 273.15, "Q", x_in, refrigerant)

geom = FinnTubedHX(
    n_seg_l = 5,        # -
    n_seg_r = 5,        # -
    stacks = 100,         # -
    n_fin = 2,           # -
    l_fin = 0.022,          # m
    h_fin = 0.022,          # m
    fin_thickness = 0.0002,    # m
    fin_pitch_cc = 0.0032,          # m
    d_tube_a = 0.00952,          # m
    tube_thickness = 0.0005,       # m
    lambda_fin = 237,            # W/mK
    rho_solid = 2700,            # kg/m3
    c_solid = 900,               # J/kgK
    CP = "row_serpentine"
)

gs = GridShape(
    t_end = 60.0,      # s endtime
    dt = 1.0,           # s time step
    store_grid_every_x_it = 10,

    nx = 100,
    nr = 100,
    ntheta = 90,

    #Model Setup
    cal_steady_state = False,
    cal_air = True,
    cal_frost = False,
    cal_ref = True
)

cfg = CaseConfig(
    # air data
    m_dot = v_a*rho_amb_in*(geom.h_fin*geom.fin_gap()*geom.n_seg_r),
    T_a = T_a,          # °C temperature air
    v_a = v_a,          # m/s velocity air
    p_a = P,            # Pa pressure air
    RH = RH,            # relative humidity air
    w_amb = w_amb_in,          # kg/kg water vapor moisture content
    rho_amb = rho_amb_in,      # kg/m^3 density air
    v_kin = 1.5e-5,     # m^2/s kinematic viscosity air
    lam = 0.025,        # W/mK heat conduction coefficient air
    c_p_a = 1000,       # J/kgK heat capacity air
    D_std = 2.2e-5,     # m^2/s water vapor diffusion coefficient
    C = 900,            # 1/s empirical water vapor absorbed coefficient
    isv = 2830000,      # J/kg latent heat of desublimation

    # refrigerant data
    ref_str = refrigerant,
    T_tube = T_a,    # °C tube temperature
    T_ref = T_a,     # °C tube temperature
    p_ref = p_ref_in,      # Pa Kältemitteldruck
    h_ref = h_ref_in,          # J/kg spezifische Enthalpie
    m_dot_ref = 1.0e-4,      # kg/s Massenstrom am Inlet
    m_dot_ref_out = 1.0e-4,      # kg/s Massenstrom am Outlet
    x_ref = x_in,           # Dampfqualität (0..1), NaN falls einphasig

    # ice data
    rho_i = 920,        # kg/m^3 ice density
    h_sub= 2830000,     # J/kg latent heat of ablimation for water vapor
)

HP = HeatPump(
    N_cond=N_cond,
    p_ref_cond = p_ref_cond,
    h_ref_cond = np.full(N_cond, h_ref_cond, dtype=float),
    T_wall = np.full(N_cond, T_in_water, dtype=float),
    T_water = np.full(N_cond, T_in_water, dtype=float),

    A_flow_cond = 0.1,
    dx_cond = 0.01,
    A_wall = 0.1,
    A_plate = 0.1,

    #water
    T_in_water = T_in_water,
    m_water = 0.01,
    c_water = 4200,
    rho_water = 997
)

plot.plot_finned_tube_side(geom)
geom.A_one_segment()*geom.n_seg_r*geom.n_seg_l*geom.stacks
# Out:
# 2.2884049669264304

# %% [markdown]
# # Simulation laufen lassen

# %%
result_file = "results_test"

if sim_run:
    sim = Simulator(geom,cfg,HP,result_file)
    results = sim.run(cfg, geom, gs, Frostmodell_V1)
# Out:
# Time Step: 1	 Time: 0.0 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=46, mean T_evap=17.56 °C, mean T_tube_evap=18.89 °C, Q_evap=1510.48 W, Q_cond=0.00 W, ct=15.979 s)
# Cycle time for time step 1: 23.2 s
# Time remaining: 23.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 2	 Time: 1.0 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=19.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=19.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=19.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=19.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=19.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=19.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=19.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=19.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=19.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=19.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=19.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=19.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=19.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=19.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=19.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=181, mean T_evap=6.45 °C, mean T_tube_evap=12.34 °C, Q_evap=1795.11 W, Q_cond=0.32 W, ct=137.732 s)
# Cycle time for time step 2: 137.9 s
# Time remaining: 135.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 3	 Time: 2.0 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=17.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.45 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.22 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=15.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=15.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=15.24 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=15.01 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=13.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=13.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=13.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=13.42 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=13.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=43, mean T_evap=-2.37 °C, mean T_tube_evap=8.05 °C, Q_evap=1494.38 W, Q_cond=1.11 W, ct=35.645 s)
# Cycle time for time step 3: 35.8 s
# Time remaining: 34.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 4	 Time: 3.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.18 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.42 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.49 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=15.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=15.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.29 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=9.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=9.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=9.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=10.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=11.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=68, mean T_evap=1.07 °C, mean T_tube_evap=5.70 °C, Q_evap=1197.18 W, Q_cond=2.30 W, ct=46.448 s)
# Cycle time for time step 4: 46.6 s
# Time remaining: 44.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 5	 Time: 4.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.95 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.88 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.65 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.45 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.37 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=15.22 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=7.34 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=7.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=8.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=8.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=9.15 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=68, mean T_evap=3.60 °C, mean T_tube_evap=4.99 °C, Q_evap=914.86 W, Q_cond=4.27 W, ct=90.896 s)
# Cycle time for time step 5: 91.0 s
# Time remaining: 84.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 6	 Time: 5.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.07 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.65 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.99 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.29 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=13.65 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=12.88 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=7.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=8.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=8.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=8.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=8.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=49, mean T_evap=4.61 °C, mean T_tube_evap=5.20 °C, Q_evap=757.22 W, Q_cond=7.15 W, ct=49.727 s)
# Cycle time for time step 6: 49.8 s
# Time remaining: 45.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 7	 Time: 6.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.02 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.88 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.38 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.63 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.63 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.42 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=13.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=7.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=8.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=8.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=9.15 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=9.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=17, mean T_evap=5.23 °C, mean T_tube_evap=5.76 °C, Q_evap=682.55 W, Q_cond=10.63 W, ct=9.979 s)
# Cycle time for time step 7: 10.1 s
# Time remaining: 9.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 8	 Time: 7.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.87 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.01 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.32 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=13.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=8.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=8.93 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=9.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=9.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=9.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=25, mean T_evap=5.89 °C, mean T_tube_evap=6.38 °C, Q_evap=636.73 W, Q_cond=14.70 W, ct=31.379 s)
# Cycle time for time step 8: 31.5 s
# Time remaining: 27.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 9	 Time: 8.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.82 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.96 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.18 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.37 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.15 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=13.82 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=8.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=9.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=9.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=10.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=10.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=15, mean T_evap=6.37 °C, mean T_tube_evap=6.89 °C, Q_evap=658.93 W, Q_cond=19.63 W, ct=9.797 s)
# Cycle time for time step 9: 9.9 s
# Time remaining: 8.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 10	 Time: 9.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.24 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.96 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.95 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.34 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.62 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=13.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=9.24 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=9.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=10.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=10.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=14, mean T_evap=6.59 °C, mean T_tube_evap=7.15 °C, Q_evap=709.00 W, Q_cond=25.18 W, ct=9.401 s)
# Cycle time for time step 10: 9.8 s
# Time remaining: 8.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 11	 Time: 10.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.15 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=9.63 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=10.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=10.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=10.85 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=14, mean T_evap=6.60 °C, mean T_tube_evap=7.19 °C, Q_evap=754.80 W, Q_cond=31.19 W, ct=9.603 s)
# Cycle time for time step 11: 9.7 s
# Time remaining: 8.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 12	 Time: 11.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.32 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=9.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=10.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=11.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=11.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=18, mean T_evap=6.53 °C, mean T_tube_evap=7.14 °C, Q_evap=779.68 W, Q_cond=37.73 W, ct=10.288 s)
# Cycle time for time step 12: 10.4 s
# Time remaining: 8.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 13	 Time: 12.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.18 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.88 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.02 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.69 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=9.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=10.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=11.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=11.32 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=10, mean T_evap=6.30 °C, mean T_tube_evap=6.96 °C, Q_evap=847.54 W, Q_cond=44.95 W, ct=15.503 s)
# Cycle time for time step 13: 15.6 s
# Time remaining: 12.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 14	 Time: 13.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.04 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.93 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.34 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.38 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=9.72 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=10.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=11.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=11.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=13, mean T_evap=5.85 °C, mean T_tube_evap=6.57 °C, Q_evap=926.49 W, Q_cond=52.67 W, ct=9.241 s)
# Cycle time for time step 14: 9.4 s
# Time remaining: 7.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 15	 Time: 14.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.96 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.37 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=15.01 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=9.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=10.22 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=11.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=11.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=14, mean T_evap=5.29 °C, mean T_tube_evap=6.05 °C, Q_evap=983.87 W, Q_cond=60.79 W, ct=8.777 s)
# Cycle time for time step 15: 8.9 s
# Time remaining: 6.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 16	 Time: 15.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.38 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.42 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.97 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=9.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=9.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=10.85 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=11.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=28, mean T_evap=4.72 °C, mean T_tube_evap=5.50 °C, Q_evap=1024.63 W, Q_cond=69.29 W, ct=11.765 s)
# Cycle time for time step 16: 11.9 s
# Time remaining: 8.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 17	 Time: 16.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.10 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.02 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.24 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=8.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=9.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=10.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=10.72 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=12, mean T_evap=3.99 °C, mean T_tube_evap=4.84 °C, Q_evap=1119.29 W, Q_cond=78.32 W, ct=1.892 s)
# Cycle time for time step 17: 2.0 s
# Time remaining: 1.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 18	 Time: 17.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.04 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.80 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.01 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=8.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=8.97 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=9.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=10.04 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=10.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=27, mean T_evap=2.88 °C, mean T_tube_evap=3.97 °C, Q_evap=1226.03 W, Q_cond=87.70 W, ct=25.674 s)
# Cycle time for time step 18: 25.8 s
# Time remaining: 18.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 19	 Time: 18.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.01 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.69 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.65 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.59 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=13.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=7.45 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=8.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=9.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=9.49 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=9.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=33, mean T_evap=1.61 °C, mean T_tube_evap=2.96 °C, Q_evap=1308.46 W, Q_cond=97.34 W, ct=49.834 s)
# Cycle time for time step 19: 50.0 s
# Time remaining: 35.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 20	 Time: 19.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.10 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.96 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.81 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.63 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.42 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.72 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=13.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=13.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=12.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=6.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=7.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=8.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=8.80 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=9.07 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=19, mean T_evap=0.31 °C, mean T_tube_evap=1.90 °C, Q_evap=1372.87 W, Q_cond=107.18 W, ct=32.195 s)
# Cycle time for time step 20: 32.6 s
# Time remaining: 22.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 21	 Time: 20.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.32 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=13.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=13.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=13.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=12.82 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=12.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=5.42 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=6.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=7.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=7.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=8.23 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=33, mean T_evap=-1.22 °C, mean T_tube_evap=0.82 °C, Q_evap=1451.69 W, Q_cond=117.32 W, ct=33.190 s)
# Cycle time for time step 21: 33.3 s
# Time remaining: 22.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 22	 Time: 21.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.82 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=15.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.22 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.45 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=13.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=13.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=12.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=12.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=11.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=4.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=5.38 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=6.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=6.87 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=7.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=31, mean T_evap=-3.14 °C, mean T_tube_evap=-0.40 °C, Q_evap=1552.05 W, Q_cond=127.74 W, ct=18.728 s)
# Cycle time for time step 22: 18.9 s
# Time remaining: 12.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 23	 Time: 22.0 s | 0.4 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.52 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.29 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=15.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=15.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=12.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=12.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=12.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=11.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=10.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=2.65 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=3.97 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=4.95 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=5.62 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=6.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=33, mean T_evap=-5.24 °C, mean T_tube_evap=-1.73 °C, Q_evap=1633.31 W, Q_cond=138.39 W, ct=25.969 s)
# Cycle time for time step 23: 26.1 s
# Time remaining: 16.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 24	 Time: 23.0 s | 0.4 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=17.82 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=15.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=15.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=15.72 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=15.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=11.97 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=11.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=11.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=10.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=9.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=0.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=2.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=3.23 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=4.02 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=4.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=36, mean T_evap=-7.45 °C, mean T_tube_evap=-3.12 °C, Q_evap=1700.82 W, Q_cond=149.21 W, ct=34.113 s)
# Cycle time for time step 24: 34.2 s
# Time remaining: 21.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 25	 Time: 24.0 s | 0.4 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=17.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=17.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=14.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=14.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=15.22 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=15.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=15.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=11.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=10.69 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=10.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=9.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=8.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=-0.69 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=-0.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=1.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=2.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=2.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=43, mean T_evap=-10.04 °C, mean T_tube_evap=-4.58 °C, Q_evap=1781.37 W, Q_cond=160.17 W, ct=62.403 s)
# Cycle time for time step 25: 62.5 s
# ...
# Seg[4,3] | Air(T=12.38 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=12.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=10, mean T_evap=10.15 °C, mean T_tube_evap=10.53 °C, Q_evap=444.68 W, Q_cond=473.40 W, ct=8.574 s)
# Cycle time for time step 53: 8.7 s
# Time remaining: 1.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 54	 Time: 53.0 s | 0.9 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.38 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.01 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.69 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.59 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=12.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=12.37 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=12.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=12.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=12.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=10, mean T_evap=10.22 °C, mean T_tube_evap=10.62 °C, Q_evap=468.48 W, Q_cond=485.67 W, ct=8.895 s)
# Cycle time for time step 54: 9.0 s
# Time remaining: 1.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 55	 Time: 54.0 s | 0.9 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.38 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.52 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.87 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.62 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=12.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=12.45 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=12.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=12.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=12.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=10, mean T_evap=10.24 °C, mean T_tube_evap=10.65 °C, Q_evap=483.76 W, Q_cond=497.97 W, ct=8.691 s)
# Cycle time for time step 55: 8.8 s
# Time remaining: 0.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 56	 Time: 55.0 s | 0.9 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.81 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.04 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.96 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.85 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.52 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=12.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=12.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=12.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=12.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=12.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=8, mean T_evap=10.23 °C, mean T_tube_evap=10.65 °C, Q_evap=490.97 W, Q_cond=510.30 W, ct=8.601 s)
# Cycle time for time step 56: 8.7 s
# Time remaining: 0.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 57	 Time: 56.0 s | 0.9 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.62 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.38 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.24 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.87 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=15.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.88 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=12.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=12.45 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=12.59 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=12.69 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=12.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=5, mean T_evap=10.22 °C, mean T_tube_evap=10.64 °C, Q_evap=490.82 W, Q_cond=522.64 W, ct=0.813 s)
# Cycle time for time step 57: 0.9 s
# Time remaining: 0.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 58	 Time: 57.0 s | 0.9 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.65 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.85 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=15.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.88 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=12.24 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=12.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=12.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=12.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=12.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=9, mean T_evap=10.24 °C, mean T_tube_evap=10.65 °C, Q_evap=484.13 W, Q_cond=534.97 W, ct=14.948 s)
# Cycle time for time step 58: 15.1 s
# Time remaining: 0.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 59	 Time: 58.0 s | 1.0 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.85 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.93 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.07 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.99 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.87 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.72 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=12.24 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=12.42 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=12.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=12.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=12.69 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=7, mean T_evap=10.29 °C, mean T_tube_evap=10.69 °C, Q_evap=471.93 W, Q_cond=547.27 W, ct=1.114 s)
# Cycle time for time step 59: 1.2 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 60	 Time: 59.0 s | 1.0 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.85 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.97 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.52 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=12.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=12.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=12.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=12.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=12.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=8, mean T_evap=10.38 °C, mean T_tube_evap=10.77 °C, Q_evap=455.58 W, Q_cond=559.56 W, ct=8.061 s)
# Cycle time for time step 60: 8.5 s
# Time remaining: 0.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 61	 Time: 60.0 s | 1.0 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.97 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=12.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=12.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=12.59 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=12.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=12.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=7, mean T_evap=10.51 °C, mean T_tube_evap=10.89 °C, Q_evap=436.37 W, Q_cond=571.81 W, ct=1.111 s)
# Cycle time for time step 61: 1.5 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Simulation ended at 2025-12-21 18:47:32
# Time to complete: 32.0 min

# %% [markdown]
# # Resultate speichen/laden

# %%
if sim_run:
    data = results.data
    results.to_csv(result_file,data)

if read_data:
    data = ResultRecorder.read_results_csv_json(result_file)
    results = ResultRecorder.from_jsonl(result_file)

# %% [markdown]
# # Resultate plotten

# %%
snapshots = results.grid_snapshots

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="v_a",
    source="cfg",
    t_idx=-1,          # letzter Zeitschritt
    title="Geschwindigkeit der Luft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="s_ft",
    source="st",       # aus SimState
    t_idx=-1,          # letzter Zeitschritt
    title="Frostdicke s_ft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_a",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Lufttemperatur T_a über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="w_amb",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="RH",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="relative Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_tube",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur der Wände über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur des Kältemittels über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="h_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Enthalpie des Kältemittels über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="p_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Druck vom Kältemittel über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="x_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="X des Kältemittel über alle Segmente",
    cmap="viridis"
)

# %%
plot.plot_any(kind="time vs any",
              x=data['t'], y=data['COP_cold'],
              xlabel="Zeit [s]", ylabel="COP",
              title=f"COP Kalt", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['COP_warm'],
              xlabel="Zeit [s]", ylabel="COP",
              title=f"COP Warm", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['mean_s_ft'],
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Durchschnittliche Frostdicke", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_air_mean'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Gemittelte Austrittstemperatur Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_ref'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Austrittstemperatur Kältemittel", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['humidity'],
              xlabel="Zeit [s]", ylabel="Feuchtegehalt [kg/kg]",
              title=f"Feuchtgehalt entlang dem Luftstrom", marker=None,
              labels=["Seg 1","Seg 2","Seg 3","Seg 4","Seg 5"])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Feuchtgehalt entlang dem Luftstrom'}, xlabel='Zeit [s]', ylabel='Feuchtegehalt [kg/kg]'>)

# %%
# Segment auswählen
ix, iy = 0, 2

plot_r = int(gs.nr-1)
plot_x = int(gs.nx-1)
plot_theta = int(gs.ntheta-1)
plot_time = int(max(data['t'])/gs.dt)

t, s_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_e", ix, iy)
plot.plot_any(kind="time vs 1D(theta)",
              x=t, y=s_e,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Edge Frostdicke bei θ_idx = {plot_theta} – Segment ({ix},{iy})",
              theta_idx=plot_theta, marker=None)
t, s_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_ft", ix, iy)
plot.plot_any(kind="time vs any",
              x=t, y=s_ft,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"F&T Frostdicke – Segment ({ix},{iy})", marker=None)
t, T_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=T_e,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Edge Frosttemperatur bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, T_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=T_ft,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"F&T Frosttemperatur bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_e,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"Edge Frostdichte bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, rho_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=rho_ft,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"F&T Frostdichte bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_a_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_a_e,
              xlabel="Zeit [s]", ylabel="Dichte der trockenen Luft [kg/m^3]",
              title=f"Edge Dichte der trockenen Luft bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, w_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=w_e,
              xlabel="Zeit [s]", ylabel="w [kg/kg]",
              title=f"Edge Feuchtigkeit bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\OneDrive\Dokumente\GitHub\MSE_VT1_luethluk\Framework\visualisation\plot.py:42, in extract_segment_timeseries_from_snapshots(grid_snapshots, field, ix, iy)
#      41 try:
# ---> 42     val = getattr(st_ij, field)
#      43 except AttributeError as e:
#
# AttributeError: 'SimState' object has no attribute 'rho_a_e'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 44
#      38 t, rho_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_ft", ix, iy)
#      39 plot.plot_any(kind="time vs 1D(r)",
#      40               x=t, y=rho_ft,
#      41               xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
#      42               title=f"F&T Frostdichte bei x_idx = {plot_x} – Segment ({ix},{iy})",
#      43               r_idx=plot_x, marker=None)
# ---> 44 t, rho_a_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e", ix, iy)
#      45 plot.plot_any(kind="time vs 2D(r,theta)",
#      46               x=t, y=rho_a_e,
#      47               xlabel="Zeit [s]", ylabel="Dichte der trockenen Luft [kg/m^3]",
#      48               title=f"Edge Dichte der trockenen Luft bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
#      49               r_idx=plot_r, theta_idx=plot_theta, marker=None)
#      50 t, w_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e", ix, iy)
#
# File ~\OneDrive\Dokumente\GitHub\MSE_VT1_luethluk\Framework\visualisation\plot.py:44, in extract_segment_timeseries_from_snapshots(grid_snapshots, field, ix, iy)
#      42     val = getattr(st_ij, field)
#      43 except AttributeError as e:
# ---> 44     raise AttributeError(
#      45         f"SimState hat kein Attribut '{field}'. "
#      46         f"Verfügbare: {list(vars(st_ij).keys())}"
#      47     ) from e
#      49 # in Array wandeln (damit Shapes vergleichbar sind)
#      50 y_list.append(np.asarray(val))
#
# AttributeError: SimState hat kein Attribut 'rho_a_e'. Verfügbare: ['t', 's_e', 'T_e', 'rho_e', 'rho_a', 'w_e', 's_ft', 'T_ft', 'rho_ft', 'w_ft']

# %%
_, T_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e",      ix, iy)
plot.plot_spatial_slice(
    T_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, T_ft      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft",      ix, iy)
plot.plot_spatial_slice(
    T_ft, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_ft(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, rho_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e",      ix, iy)
plot.plot_spatial_slice(
    rho_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_e [kg/m^3]", marker=None
)
_, w_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e",      ix, iy)
plot.plot_spatial_slice(
    w_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"w_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="w_e [kg/kg]", marker=None
)
_, rho_a_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e",      ix, iy)
plot.plot_spatial_slice(
    rho_a_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_a(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_a [kg/m^3]", marker=None
)
