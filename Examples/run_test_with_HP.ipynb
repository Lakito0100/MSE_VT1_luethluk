# %%
from pathlib import Path
import sys
import numpy as np
from CoolProp.HumidAirProp import HAPropsSI
from CoolProp.CoolProp import PropsSI
sys.path.insert(0, str(Path.cwd().parent))
from Framework.core.config import CaseConfig, GridShape, HeatPump
from Framework.core.geometry import FinnTubedHX
from Framework.models import Frostmodell_V1
from Framework.runtime.simulator_V2 import Simulator
from Framework.visualisation import plot
from Framework.runtime.recorder import ResultRecorder

# %% [markdown]
# # Case Definieren

# %%
sim_run = True
read_data = True

#air
T_a = 20.0
P = 101325
RH = 0.1
v_a = 1.2

#refrigerant
w_amb_in = HAPropsSI('W','T',T_a+273.15,'P',P,'R', RH)
rho_amb_in = 1.0 / HAPropsSI("Vha","T",T_a+273.15,"P",P,"R",RH)

refrigerant = "R134a"
#at evaportor
x_in = 0.5
p_ref_in = PropsSI("P", "T", T_a + 273.15, "Q", x_in, refrigerant)
h_ref_in = PropsSI("H", "T", T_a + 273.15, "Q", x_in, refrigerant)

#water
T_in_water = 30.0
N_cond = 22

#at condenser
p_ref_cond = PropsSI("P", "T", T_in_water + 273.15, "Q", x_in, refrigerant)
h_ref_cond = PropsSI("H", "T", T_in_water + 273.15, "Q", x_in, refrigerant)

geom = FinnTubedHX(
    n_seg_l = 2,        # -
    n_seg_r = 20,        # -
    stacks = 150,         # -
    n_fin = 2,           # -
    l_fin = 0.022,          # m
    h_fin = 0.022,          # m
    fin_thickness = 0.0002,    # m
    fin_pitch_cc = 0.0032,          # m
    d_tube_a = 0.00952,          # m
    tube_thickness = 0.0005,       # m
    lambda_fin = 237,            # W/mK
    rho_solid = 8000,            # kg/m3
    c_solid = 500,               # J/kgK
    CP = "row_serpentine"
)

gs = GridShape(
    t_end = 10*60.0,      # s endtime
    dt = 1.0,           # s time step
    store_grid_every_x_it = 10,

    nx = 100,
    nr = 100,
    ntheta = 90,

    #Model Setup
    cal_steady_state = False,
    cal_air = True,
    cal_frost = False,
    cal_ref = True
)

cfg = CaseConfig(
    # air data
    m_dot = v_a*rho_amb_in*(geom.h_fin*geom.fin_gap()*geom.n_seg_r),
    T_a = T_a,          # °C temperature air
    v_a = v_a,          # m/s velocity air
    p_a = P,            # Pa pressure air
    RH = RH,            # relative humidity air
    w_amb = w_amb_in,          # kg/kg water vapor moisture content
    rho_amb = rho_amb_in,      # kg/m^3 density air
    v_kin = 1.5e-5,     # m^2/s kinematic viscosity air
    lam = 0.025,        # W/mK heat conduction coefficient air
    c_p_a = 1000,       # J/kgK heat capacity air
    D_std = 2.2e-5,     # m^2/s water vapor diffusion coefficient
    C = 900,            # 1/s empirical water vapor absorbed coefficient
    isv = 2830000,      # J/kg latent heat of desublimation

    # refrigerant data
    ref_str = refrigerant,
    T_tube = T_a,    # °C tube temperature
    T_ref = T_a,     # °C tube temperature
    p_ref = p_ref_in,      # Pa Kältemitteldruck
    h_ref = h_ref_in,          # J/kg spezifische Enthalpie
    m_dot_ref = 1.0e-4,      # kg/s Massenstrom am Inlet (invalid)
    m_dot_ref_out = 1.0e-4,      # kg/s Massenstrom am Outlet (invalid)
    x_ref = x_in,           # Dampfqualität (0..1), NaN falls einphasig

    # ice data
    rho_i = 920,        # kg/m^3 ice density
    h_sub= 2830000,     # J/kg latent heat of ablimation for water vapor
)

HP = HeatPump(
    N_cond=N_cond,
    p_ref_cond = p_ref_cond,
    h_ref_cond = np.full(N_cond, h_ref_cond, dtype=float),
    T_wall = np.full(N_cond, T_in_water, dtype=float),
    T_water = np.full(N_cond, T_in_water, dtype=float),

    A_flow_cond = 0.01,
    dx_cond = 0.5/N_cond,
    t_plate = 0.001,
    height_cond=1.0,
    A_plate = 3.65,
    c_plate = 500,
    rho_plate = 8000.0,
    lamda_plate = 50.0,

    #water
    T_in_water = T_in_water,
    m_water = 0.35,
    c_water = 4200,
    rho_water = 997
)

plot.plot_finned_tube_side(geom)
print(f"Surface area Evaporator = {geom.A_one_segment()*geom.n_seg_r*geom.n_seg_l*geom.stacks:.2f} m2")
print(f"Surface area Condenser = {HP.A_plate:.2f} m2")
# Out:
# Surface area Evaporator = 5.49 m2
# Surface area Condenser = 3.65 m2

# %% [markdown]
# # Simulation laufen lassen

# %%
result_file = "results_test"

if sim_run:
    sim = Simulator(geom,cfg,HP,result_file)
    results = sim.run(cfg, geom, gs, Frostmodell_V1)
# Out:
# Time Step: 1	 Time: 0.0 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=39, mean T_evap=19.04 °C, mean T_tube_evap=19.70 °C, Q_evap=1790.02 W, Q_cond=280.72 W, ct=5.910 s)
# Cycle time for time step 1: 9.9 s
# Time remaining: 98.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 2	 Time: 1.0 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.89 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=48, mean T_evap=15.50 °C, mean T_tube_evap=17.06 °C, Q_evap=3909.11 W, Q_cond=2078.07 W, ct=5.167 s)
# Cycle time for time step 2: 5.4 s
# Time remaining: 53.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 3	 Time: 2.0 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=208, mean T_evap=15.90 °C, mean T_tube_evap=16.19 °C, Q_evap=795.00 W, Q_cond=3289.79 W, ct=28.553 s)
# Cycle time for time step 3: 28.9 s
# Time remaining: 287.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 4	 Time: 3.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.03 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.03 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.02 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=18.99 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=18.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=50, mean T_evap=15.22 °C, mean T_tube_evap=15.94 °C, Q_evap=1126.60 W, Q_cond=2924.38 W, ct=10.217 s)
# Cycle time for time step 4: 10.5 s
# Time remaining: 104.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 5	 Time: 4.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.13 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.14 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.13 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.13 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.12 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.12 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=37, mean T_evap=14.35 °C, mean T_tube_evap=15.48 °C, Q_evap=1349.34 W, Q_cond=2745.73 W, ct=5.963 s)
# Cycle time for time step 5: 6.2 s
# Time remaining: 61.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 6	 Time: 5.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.20 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=27, mean T_evap=13.36 °C, mean T_tube_evap=14.98 °C, Q_evap=1468.46 W, Q_cond=2808.01 W, ct=1.390 s)
# Cycle time for time step 6: 1.6 s
# Time remaining: 15.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 7	 Time: 6.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=30, mean T_evap=12.70 °C, mean T_tube_evap=14.48 °C, Q_evap=1599.42 W, Q_cond=2959.67 W, ct=3.014 s)
# Cycle time for time step 7: 3.2 s
# Time remaining: 31.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 8	 Time: 7.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.46 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=37, mean T_evap=11.80 °C, mean T_tube_evap=13.97 °C, Q_evap=1695.86 W, Q_cond=3144.88 W, ct=3.896 s)
# Cycle time for time step 8: 4.1 s
# Time remaining: 40.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 9	 Time: 8.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.52 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.55 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.57 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.57 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.57 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.57 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.57 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.57 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.57 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.57 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=27, mean T_evap=11.04 °C, mean T_tube_evap=13.46 °C, Q_evap=1812.40 W, Q_cond=3342.67 W, ct=2.740 s)
# Cycle time for time step 9: 2.9 s
# Time remaining: 28.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 10	 Time: 9.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.60 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=28, mean T_evap=10.27 °C, mean T_tube_evap=12.95 °C, Q_evap=1949.28 W, Q_cond=3543.85 W, ct=2.066 s)
# Cycle time for time step 10: 2.9 s
# Time remaining: 28.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 11	 Time: 10.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.55 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.59 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.65 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.67 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.68 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.69 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.72 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=30, mean T_evap=9.24 °C, mean T_tube_evap=12.42 °C, Q_evap=2060.11 W, Q_cond=3749.59 W, ct=3.532 s)
# Cycle time for time step 11: 3.7 s
# Time remaining: 36.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 12	 Time: 11.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.60 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.69 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.71 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.72 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=20, mean T_evap=8.15 °C, mean T_tube_evap=11.87 °C, Q_evap=2216.83 W, Q_cond=3967.43 W, ct=1.345 s)
# Cycle time for time step 12: 1.5 s
# Time remaining: 15.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 13	 Time: 12.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.67 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.72 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.82 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=44, mean T_evap=6.70 °C, mean T_tube_evap=11.26 °C, Q_evap=2414.47 W, Q_cond=4206.82 W, ct=9.619 s)
# Cycle time for time step 13: 9.9 s
# Time remaining: 96.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 14	 Time: 13.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.67 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.73 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.80 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.81 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.82 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.82 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.82 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=23, mean T_evap=4.96 °C, mean T_tube_evap=10.59 °C, Q_evap=2650.25 W, Q_cond=4478.81 W, ct=3.430 s)
# Cycle time for time step 14: 3.6 s
# Time remaining: 35.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 15	 Time: 14.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.73 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.81 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.82 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=48, mean T_evap=2.49 °C, mean T_tube_evap=9.80 °C, Q_evap=2944.00 W, Q_cond=4795.69 W, ct=8.954 s)
# Cycle time for time step 15: 9.2 s
# Time remaining: 89.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 16	 Time: 15.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.72 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.75 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.81 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.87 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.87 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.95 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=62, mean T_evap=-1.47 °C, mean T_tube_evap=8.88 °C, Q_evap=3307.80 W, Q_cond=5128.04 W, ct=8.142 s)
# Cycle time for time step 16: 8.3 s
# Time remaining: 81.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 17	 Time: 16.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.73 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.79 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.81 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.86 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.87 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# ...
# Seg[1,1] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=6.69 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=7.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=11.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=12.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=12.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=2, mean T_evap=-21.09 °C, mean T_tube_evap=-17.02 °C, Q_evap=6138.67 W, Q_cond=9531.16 W, ct=1.416 s)
# Cycle time for time step 596: 1.7 s
# Time remaining: 0.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 597	 Time: 596.0 s | 9.9 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=6.69 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=7.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=11.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=12.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=12.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=1, mean T_evap=-21.09 °C, mean T_tube_evap=-17.02 °C, Q_evap=6138.67 W, Q_cond=9531.16 W, ct=0.013 s)
# Cycle time for time step 597: 0.3 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 598	 Time: 597.0 s | 9.9 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=6.69 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=7.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=11.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=12.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=12.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=1, mean T_evap=-21.09 °C, mean T_tube_evap=-17.02 °C, Q_evap=6138.67 W, Q_cond=9531.16 W, ct=1.394 s)
# Cycle time for time step 598: 1.7 s
# Time remaining: 0.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 599	 Time: 598.0 s | 10.0 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=6.69 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=7.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=11.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=12.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=12.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=1, mean T_evap=-21.09 °C, mean T_tube_evap=-17.02 °C, Q_evap=6138.67 W, Q_cond=9531.16 W, ct=0.020 s)
# Cycle time for time step 599: 0.3 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 600	 Time: 599.0 s | 10.0 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=6.69 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=7.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=11.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=12.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=12.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=1, mean T_evap=-21.09 °C, mean T_tube_evap=-17.02 °C, Q_evap=6138.67 W, Q_cond=9531.16 W, ct=0.019 s)
# Cycle time for time step 600: 1.1 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 601	 Time: 600.0 s | 10.0 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=6.64 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=6.69 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=7.84 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=11.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=12.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=12.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=1, mean T_evap=-21.09 °C, mean T_tube_evap=-17.02 °C, Q_evap=6138.67 W, Q_cond=9531.16 W, ct=0.020 s)
# Cycle time for time step 601: 1.0 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Simulation ended at 2025-12-23 08:14:08
# Time to complete: 11.4 min

# %% [markdown]
# # Resultate speichen/laden

# %%
if sim_run:
    data = results.data
    results.to_csv(result_file,data)

if read_data:
    data = ResultRecorder.read_results_csv_json(result_file)
    results = ResultRecorder.from_jsonl(result_file)

# %% [markdown]
# # Resultate plotten

# %%
snapshots = results.grid_snapshots

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="v_a",
    source="cfg",
    t_idx=-1,          # letzter Zeitschritt
    title="Geschwindigkeit der Luft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="s_ft",
    source="st",       # aus SimState
    t_idx=-1,          # letzter Zeitschritt
    title="Frostdicke s_ft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_a",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Lufttemperatur T_a über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="w_amb",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="RH",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="relative Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_tube",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur der Wände über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur des Kältemittels über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="h_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Enthalpie des Kältemittels über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="p_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Druck vom Kältemittel über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="x_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="X des Kältemittel über alle Segmente",
    cmap="viridis"
)

# %%
plot.plot_any(kind="time vs any",
              x=data['t'], y=data['EER'],
              xlabel="Zeit [s]", ylabel="EER",
              title=f"EER", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['COP'],
              xlabel="Zeit [s]", ylabel="COP",
              title=f"COP", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['mean_s_ft'],
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Durchschnittliche Frostdicke", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_air_mean'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Gemittelte Austrittstemperatur Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_ref'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Austrittstemperatur Kältemittel", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_evap'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Verdampferseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_cond'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Kondenserseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['humidity'],
              xlabel="Zeit [s]", ylabel="Feuchtegehalt [kg/kg]",
              title=f"Feuchtgehalt entlang dem Luftstrom", marker=None,
              labels=["Seg 1","Seg 2","Seg 3","Seg 4","Seg 5"])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Feuchtgehalt entlang dem Luftstrom'}, xlabel='Zeit [s]', ylabel='Feuchtegehalt [kg/kg]'>)

# %%
# Segment auswählen
ix, iy = 0, 2

plot_r = int(gs.nr-1)
plot_x = int(gs.nx-1)
plot_theta = int(gs.ntheta-1)
plot_time = int(max(data['t'])/gs.dt)

t, s_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_e", ix, iy)
plot.plot_any(kind="time vs 1D(theta)",
              x=t, y=s_e,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Edge Frostdicke bei θ_idx = {plot_theta} – Segment ({ix},{iy})",
              theta_idx=plot_theta, marker=None)
t, s_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_ft", ix, iy)
plot.plot_any(kind="time vs any",
              x=t, y=s_ft,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"F&T Frostdicke – Segment ({ix},{iy})", marker=None)
t, T_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=T_e,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Edge Frosttemperatur bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, T_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=T_ft,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"F&T Frosttemperatur bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_e,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"Edge Frostdichte bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, rho_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=rho_ft,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"F&T Frostdichte bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_a_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_a_e,
              xlabel="Zeit [s]", ylabel="Dichte der trockenen Luft [kg/m^3]",
              title=f"Edge Dichte der trockenen Luft bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, w_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=w_e,
              xlabel="Zeit [s]", ylabel="w [kg/kg]",
              title=f"Edge Feuchtigkeit bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\OneDrive\Dokumente\GitHub\MSE_VT1_luethluk\Framework\visualisation\plot.py:42, in extract_segment_timeseries_from_snapshots(grid_snapshots, field, ix, iy)
#      41 try:
# ---> 42     val = getattr(st_ij, field)
#      43 except AttributeError as e:
#
# AttributeError: 'SimState' object has no attribute 'rho_a_e'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 44
#      38 t, rho_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_ft", ix, iy)
#      39 plot.plot_any(kind="time vs 1D(r)",
#      40               x=t, y=rho_ft,
#      41               xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
#      42               title=f"F&T Frostdichte bei x_idx = {plot_x} – Segment ({ix},{iy})",
#      43               r_idx=plot_x, marker=None)
# ---> 44 t, rho_a_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e", ix, iy)
#      45 plot.plot_any(kind="time vs 2D(r,theta)",
#      46               x=t, y=rho_a_e,
#      47               xlabel="Zeit [s]", ylabel="Dichte der trockenen Luft [kg/m^3]",
#      48               title=f"Edge Dichte der trockenen Luft bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
#      49               r_idx=plot_r, theta_idx=plot_theta, marker=None)
#      50 t, w_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e", ix, iy)
#
# File ~\OneDrive\Dokumente\GitHub\MSE_VT1_luethluk\Framework\visualisation\plot.py:44, in extract_segment_timeseries_from_snapshots(grid_snapshots, field, ix, iy)
#      42     val = getattr(st_ij, field)
#      43 except AttributeError as e:
# ---> 44     raise AttributeError(
#      45         f"SimState hat kein Attribut '{field}'. "
#      46         f"Verfügbare: {list(vars(st_ij).keys())}"
#      47     ) from e
#      49 # in Array wandeln (damit Shapes vergleichbar sind)
#      50 y_list.append(np.asarray(val))
#
# AttributeError: SimState hat kein Attribut 'rho_a_e'. Verfügbare: ['t', 's_e', 'T_e', 'rho_e', 'rho_a', 'w_e', 's_ft', 'T_ft', 'rho_ft', 'w_ft']

# %%
_, T_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e",      ix, iy)
plot.plot_spatial_slice(
    T_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, T_ft      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft",      ix, iy)
plot.plot_spatial_slice(
    T_ft, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_ft(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, rho_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e",      ix, iy)
plot.plot_spatial_slice(
    rho_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_e [kg/m^3]", marker=None
)
_, w_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e",      ix, iy)
plot.plot_spatial_slice(
    w_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"w_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="w_e [kg/kg]", marker=None
)
_, rho_a_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e",      ix, iy)
plot.plot_spatial_slice(
    rho_a_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_a(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_a [kg/m^3]", marker=None
)
