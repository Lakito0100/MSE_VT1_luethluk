# %%
from pathlib import Path
import sys
import numpy as np
from CoolProp.HumidAirProp import HAPropsSI
from CoolProp.CoolProp import PropsSI
sys.path.insert(0, str(Path.cwd().parent))
from Framework.core.config import CaseConfig, GridShape, HeatPump
from Framework.core.geometry import FinnTubedHX
from Framework.models import Frostmodell_V1
from Framework.runtime.simulator_V2 import Simulator
from Framework.visualisation import plot
from Framework.runtime.recorder import ResultRecorder

# %% [markdown]
# # Case Definieren

# %%
sim_run = True
read_data = True

#air
T_a = 10.0
P = 101325
RH = 0.1
v_a = 1.2

#water
T_in_water = 30.0
N_cond = 22

#refrigerant
w_amb_in = HAPropsSI('W','T',T_a+273.15,'P',P,'R', RH)
rho_amb_in = 1.0 / HAPropsSI("Vha","T",T_a+273.15,"P",P,"R",RH)

refrigerant = "R134a"
#at evaportor
p_ref_evap = PropsSI("P", "T", T_a + 273.15, "Q", 0.5, refrigerant)
h_ref_evap = PropsSI("H", "T", T_a + 273.15, "Q", 0.5, refrigerant)

#at condenser
p_ref_cond = PropsSI("P", "T", T_in_water + 273.15, "Q", 0.5, refrigerant)
h_ref_cond = PropsSI("H", "T", T_in_water + 273.15, "Q", 0.5, refrigerant)

geom = FinnTubedHX(
    n_seg_l = 2,        # -
    n_seg_r = 20,        # -
    stacks = 150,         # -
    n_fin = 2,           # -
    l_fin = 0.022,          # m
    h_fin = 0.022,          # m
    fin_thickness = 0.0002,    # m
    fin_pitch_cc = 0.0032,          # m
    d_tube_a = 0.00952,          # m
    tube_thickness = 0.0005,       # m
    lambda_fin = 237,            # W/mK
    rho_solid = 2700,            # kg/m3
    c_solid = 900,               # J/kgK
    CP = "row_serpentine"
)

gs = GridShape(
    t_end = 60.0,      # s endtime
    dt = 0.1,           # s time step
    store_grid_every_x_it = 50,

    nx = 100,
    nr = 100,
    ntheta = 90,

    #Model Setup
    cal_steady_state = False,
    cal_air = True,
    cal_frost = False,
    cal_ref = True
)

cfg = CaseConfig(
    # air data
    m_dot = v_a*rho_amb_in*(geom.h_fin*geom.fin_gap()*geom.n_seg_r*geom.stacks), # Backup massflow if no fan is used
    T_a = T_a,          # °C temperature air
    v_a = v_a,          # m/s velocity air
    p_a = P,            # Pa pressure air
    RH = RH,            # relative humidity air
    w_amb = w_amb_in,          # kg/kg water vapor moisture content
    rho_amb = rho_amb_in,      # kg/m^3 density air
    v_kin = 1.5e-5,     # m^2/s kinematic viscosity air
    lam = 0.025,        # W/mK heat conduction coefficient air
    c_p_a = 1000,       # J/kgK heat capacity air
    D_std = 2.2e-5,     # m^2/s water vapor diffusion coefficient
    C = 900,            # 1/s empirical water vapor absorbed coefficient
    isv = 2830000,      # J/kg latent heat of desublimation

    # fan model
    use_fan = True,
    fan_dp0 = 150.0,
    fan_V0 = v_a*(geom.h_fin*geom.fin_gap()*geom.n_seg_r*geom.stacks),
    dp_clean = 40.0,


    # refrigerant data
    ref_str = refrigerant,
    T_tube = T_a,    # °C tube temperature
    T_ref = T_a,     # °C tube temperature
    p_ref = p_ref_evap,      # Pa Kältemitteldruck
    h_ref = h_ref_evap,          # J/kg spezifische Enthalpie
    m_dot_ref = 0,      # kg/s Massenstrom am Inlet (invalid)
    m_dot_ref_out = 0,      # kg/s Massenstrom am Outlet (invalid)
    x_ref = float("nan"),           # Dampfqualität (0..1), NaN falls einphasig

    # ice data
    rho_i = 920,        # kg/m^3 ice density
    h_sub= 2830000,     # J/kg latent heat of ablimation for water vapor
)

HP = HeatPump(
    N_cond=N_cond,
    p_ref_cond = p_ref_cond,
    h_ref_cond = np.full(N_cond, h_ref_cond, dtype=float),
    T_wall = np.full(N_cond, T_in_water, dtype=float),
    T_water = np.full(N_cond, T_in_water, dtype=float),

    A_flow_cond = 0.01,
    dx_cond = 0.5/N_cond,
    t_plate = 0.001,
    height_cond=1.0,
    A_plate = 3.65,
    c_plate = 500,
    rho_plate = 8000.0,
    lamda_plate = 50.0,

    #water
    T_in_water = T_in_water,
    m_water = 0.5,
    c_water = 4200,
    rho_water = 997
)

plot.plot_finned_tube_side(geom)
print(f"Surface area Evaporator = {geom.A_one_segment()*geom.n_seg_r*geom.n_seg_l*geom.stacks:.2f} m2")
print(f"Surface area Condenser = {HP.A_plate:.2f} m2")
# Out:
# Surface area Evaporator = 5.49 m2
# Surface area Condenser = 3.65 m2

# %% [markdown]
# # Simulation laufen lassen

# %%
result_file = "results_test"

if sim_run:
    sim = Simulator(geom,cfg,HP,result_file)
    results = sim.run(cfg, geom, gs, Frostmodell_V1)
# Out:
# Time Step: 1	 Time: 0.0 s | 0.0 min
# Seg[0,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=16, evap_out=TP(x=0.500, Tsat=10.46°C, T=10.46°C), cond_out=TP(x=0.501, Tsat=29.95°C, T=29.95°C), Q_evap=-993.25 W, Q_cond=-178.48 W, ct=0.251 s)
# Updating dt for the next time step to dt=0.08
# Cycle time for time step 1: 0.7 s
# Time remaining: 8.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 2	 Time: 0.1 s | 0.0 min
# Seg[0,0] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=6, evap_out=TP(x=0.498, Tsat=10.56°C, T=10.56°C), cond_out=TP(x=0.502, Tsat=29.93°C, T=29.93°C), Q_evap=-964.46 W, Q_cond=-329.80 W, ct=0.062 s)
# Updating dt for the next time step to dt=0.10
# Cycle time for time step 2: 0.2 s
# Time remaining: 1.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 3	 Time: 0.2 s | 0.0 min
# Seg[0,0] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.08 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=10, evap_out=TP(x=0.492, Tsat=10.61°C, T=10.61°C), cond_out=TP(x=0.503, Tsat=29.93°C, T=29.93°C), Q_evap=-762.30 W, Q_cond=-431.19 W, ct=0.849 s)
# Updating dt for the next time step to dt=0.10
# Cycle time for time step 3: 1.0 s
# Time remaining: 9.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 4	 Time: 0.3 s | 0.0 min
# Seg[0,0] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=9, evap_out=TP(x=0.486, Tsat=10.61°C, T=10.61°C), cond_out=TP(x=0.504, Tsat=29.94°C, T=29.94°C), Q_evap=-530.32 W, Q_cond=-442.68 W, ct=0.852 s)
# Updating dt for the next time step to dt=0.11
# Cycle time for time step 4: 1.0 s
# Time remaining: 9.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 5	 Time: 0.4 s | 0.0 min
# Seg[0,0] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.16 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=13, evap_out=TP(x=0.482, Tsat=10.57°C, T=10.57°C), cond_out=TP(x=0.505, Tsat=29.95°C, T=29.95°C), Q_evap=-282.85 W, Q_cond=-386.21 W, ct=0.137 s)
# Updating dt for the next time step to dt=0.09
# Cycle time for time step 5: 0.3 s
# Time remaining: 2.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 6	 Time: 0.5 s | 0.0 min
# Seg[0,0] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=6, evap_out=TP(x=0.481, Tsat=10.50°C, T=10.50°C), cond_out=TP(x=0.506, Tsat=29.97°C, T=29.97°C), Q_evap=-66.91 W, Q_cond=-296.70 W, ct=0.795 s)
# Updating dt for the next time step to dt=0.12
# Cycle time for time step 6: 1.0 s
# Time remaining: 8.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 7	 Time: 0.6 s | 0.0 min
# Seg[0,0] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=6, evap_out=TP(x=0.484, Tsat=10.38°C, T=10.38°C), cond_out=TP(x=0.506, Tsat=29.99°C, T=29.99°C), Q_evap=210.37 W, Q_cond=-144.10 W, ct=0.144 s)
# Updating dt for the next time step to dt=0.16
# Cycle time for time step 7: 0.5 s
# Time remaining: 2.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 8	 Time: 0.7 s | 0.0 min
# Seg[0,0] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.27 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=8, evap_out=TP(x=0.494, Tsat=10.15°C, T=10.15°C), cond_out=TP(x=0.507, Tsat=30.02°C, T=30.02°C), Q_evap=557.49 W, Q_cond=91.60 W, ct=1.269 s)
# Updating dt for the next time step to dt=0.18
# Cycle time for time step 8: 1.5 s
# Time remaining: 8.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 9	 Time: 0.9 s | 0.0 min
# Seg[0,0] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=6, evap_out=TP(x=0.513, Tsat=9.80°C, T=9.80°C), cond_out=TP(x=0.506, Tsat=30.07°C, T=30.07°C), Q_evap=938.10 W, Q_cond=385.57 W, ct=0.131 s)
# Updating dt for the next time step to dt=0.23
# Cycle time for time step 9: 0.3 s
# Time remaining: 1.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 10	 Time: 1.0 s | 0.0 min
# Seg[0,0] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=10.05 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=10.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=9, evap_out=TP(x=0.551, Tsat=9.24°C, T=9.24°C), cond_out=TP(x=0.502, Tsat=30.13°C, T=30.13°C), Q_evap=1412.47 W, Q_cond=790.81 W, ct=1.311 s)
# Updating dt for the next time step to dt=0.24
# Cycle time for time step 10: 1.5 s
# Time remaining: 6.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 11	 Time: 1.3 s | 0.0 min
# Seg[0,0] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=16, evap_out=TP(x=0.609, Tsat=8.51°C, T=8.51°C), cond_out=TP(x=0.494, Tsat=30.20°C, T=30.20°C), Q_evap=1890.17 W, Q_cond=1235.07 W, ct=0.292 s)
# Updating dt for the next time step to dt=0.19
# Cycle time for time step 11: 0.5 s
# Time remaining: 2.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 12	 Time: 1.5 s | 0.0 min
# Seg[0,0] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=12, evap_out=TP(x=0.671, Tsat=7.85°C, T=7.85°C), cond_out=TP(x=0.490, Tsat=30.26°C, T=30.26°C), Q_evap=2249.36 W, Q_cond=1593.13 W, ct=1.089 s)
# Updating dt for the next time step to dt=0.17
# Cycle time for time step 12: 1.3 s
# Time remaining: 7.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 13	 Time: 1.7 s | 0.0 min
# Seg[0,0] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=9.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=16, evap_out=TP(x=0.743, Tsat=7.20°C, T=7.20°C), cond_out=TP(x=0.492, Tsat=30.32°C, T=30.32°C), Q_evap=2553.84 W, Q_cond=1921.63 W, ct=1.149 s)
# Updating dt for the next time step to dt=0.14
# Cycle time for time step 13: 1.3 s
# Time remaining: 9.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 14	 Time: 1.9 s | 0.0 min
# Seg[0,0] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.30 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=8.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=11, evap_out=TP(x=0.810, Tsat=6.66°C, T=6.66°C), cond_out=TP(x=0.501, Tsat=30.36°C, T=30.36°C), Q_evap=2776.52 W, Q_cond=2179.31 W, ct=1.342 s)
# Updating dt for the next time step to dt=0.13
# Cycle time for time step 14: 1.5 s
# Time remaining: 11.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 15	 Time: 2.0 s | 0.0 min
# Seg[0,0] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=9.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=8.60 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=31, evap_out=TP(x=0.873, Tsat=6.09°C, T=6.09°C), cond_out=TP(x=0.520, Tsat=30.41°C, T=30.41°C), Q_evap=2724.44 W, Q_cond=2419.99 W, ct=3.456 s)
# Updating dt for the next time step to dt=0.07
# Cycle time for time step 15: 3.6 s
# Time remaining: 47.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 16	 Time: 2.1 s | 0.0 min
# Seg[0,0] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=8.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=8.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=8.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=8.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=8.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=8.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=8.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=8.34 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.35 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=8.34 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=8.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=8.32 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=34, evap_out=TP(x=0.898, Tsat=5.60°C, T=5.60°C), cond_out=TP(x=0.534, Tsat=30.43°C, T=30.43°C), Q_evap=2646.36 W, Q_cond=2549.06 W, ct=4.467 s)
# Updating dt for the next time step to dt=0.04
# Cycle time for time step 16: 4.6 s
# Time remaining: 110.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 17	 Time: 2.2 s | 0.0 min
# Seg[0,0] | Air(T=8.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=8.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=8.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=9.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=9.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=8.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=8.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=8.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=8.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=8.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=8.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=8.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# ...
# Seg[1,3] | Air(T=-3.39 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-2.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-1.50 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-1.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-0.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-0.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-0.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-0.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-0.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-0.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-0.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-0.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-0.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-0.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-0.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-0.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=3.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=15, evap_out=SH=44.44K (Tsat=-20.58°C, T=23.86°C), cond_out=TP(x=0.035, Tsat=31.63°C, T=31.63°C), Q_evap=8376.44 W, Q_cond=9124.08 W, ct=1.074 s)
# Updating dt for the next time step to dt=0.02
# Cycle time for time step 198: 1.3 s
# Time remaining: 36.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 199	 Time: 24.9 s | 0.4 min
# Seg[0,0] | Air(T=1.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=1.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=2.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=4.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=5.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=7.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=8.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.53 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=16.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-4.61 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-4.54 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-4.24 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-3.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-2.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-1.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-1.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-0.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-0.86 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-0.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-0.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-0.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-0.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-0.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-0.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-0.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-0.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-0.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-0.83 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=3.24 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=9, evap_out=SH=43.70K (Tsat=-20.46°C, T=23.24°C), cond_out=TP(x=0.034, Tsat=31.64°C, T=31.64°C), Q_evap=8448.70 W, Q_cond=9203.20 W, ct=2.170 s)
# Updating dt for the next time step to dt=0.02
# Cycle time for time step 199: 2.3 s
# Time remaining: 64.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 200	 Time: 24.9 s | 0.4 min
# Seg[0,0] | Air(T=1.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=1.71 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=2.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=3.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=5.29 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=7.24 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=8.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.41 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.95 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=16.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-4.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-4.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-4.48 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-3.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-3.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-2.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-1.31 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-0.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-0.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-0.81 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-0.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-0.79 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-0.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-0.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-0.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-0.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-0.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-0.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-0.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=3.21 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=30, evap_out=SH=42.46K (Tsat=-20.36°C, T=22.10°C), cond_out=TP(x=0.034, Tsat=31.66°C, T=31.66°C), Q_evap=8489.76 W, Q_cond=9284.81 W, ct=2.862 s)
# Updating dt for the next time step to dt=0.02
# Cycle time for time step 200: 3.8 s
# Time remaining: 111.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 201	 Time: 24.9 s | 0.4 min
# Seg[0,0] | Air(T=0.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=1.51 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=2.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=3.40 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=4.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=6.58 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=8.39 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.25 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.65 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.84 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.93 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.98 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=16.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-5.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-4.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-4.70 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-4.23 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-3.53 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-2.52 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-1.49 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-1.04 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-0.85 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-0.78 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-0.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-0.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-0.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-0.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-0.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-0.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-0.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-0.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-0.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=3.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=17, evap_out=SH=41.65K (Tsat=-20.26°C, T=21.39°C), cond_out=TP(x=0.034, Tsat=31.67°C, T=31.67°C), Q_evap=8540.72 W, Q_cond=9359.51 W, ct=2.412 s)
# Updating dt for the next time step to dt=0.02
# Cycle time for time step 201: 2.6 s
# Time remaining: 75.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 202	 Time: 25.0 s | 0.4 min
# Seg[0,0] | Air(T=0.74 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=1.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=2.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=3.07 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=4.34 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=6.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=7.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=9.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.57 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.91 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.97 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=10.00 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=15.92 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-5.18 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-5.13 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-4.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-4.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-3.80 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-2.88 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-1.73 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-1.12 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-0.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-0.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-0.72 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-0.69 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-0.68 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-0.68 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-0.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-0.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-0.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-0.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-0.67 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=3.14 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=10, evap_out=SH=40.87K (Tsat=-20.16°C, T=20.71°C), cond_out=TP(x=0.033, Tsat=31.68°C, T=31.68°C), Q_evap=8594.41 W, Q_cond=9431.75 W, ct=1.252 s)
# Updating dt for the next time step to dt=0.02
# Cycle time for time step 202: 1.5 s
# Time remaining: 44.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 203	 Time: 25.0 s | 0.4 min
# Seg[0,0] | Air(T=0.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=1.17 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=1.87 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=2.77 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=3.94 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=5.46 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=7.45 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=8.82 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=9.45 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=9.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=9.89 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=9.96 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=9.99 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=10.01 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=10.02 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=10.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=15.76 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-5.33 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-5.28 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-5.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-4.66 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-4.06 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-3.20 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-2.03 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-1.24 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-0.90 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-0.75 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-0.69 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-0.65 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-0.64 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-0.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-0.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-0.63 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-0.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-0.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-0.62 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=3.09 °C, w=7.579e-04 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...

# %% [markdown]
# # Resultate speichen/laden

# %%
if sim_run:
    data = results.data
    results.to_csv(result_file,data)

if read_data:
    data = ResultRecorder.read_results_csv_json(result_file)
    results = ResultRecorder.from_jsonl(result_file)

# %% [markdown]
# # Resultate plotten

# %%
snapshots = results.grid_snapshots

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="v_a",
    source="cfg",
    t_idx=-1,          # letzter Zeitschritt
    title="Geschwindigkeit der Luft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="s_ft",
    source="st",       # aus SimState
    t_idx=-1,          # letzter Zeitschritt
    title="Frostdicke s_ft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_a",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Lufttemperatur T_a über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="w_amb",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="RH",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="relative Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_tube",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur der Wände über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur des Kältemittels über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="h_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Enthalpie des Kältemittels über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="p_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Druck vom Kältemittel über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="x_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="X des Kältemittel über alle Segmente",
    cmap="viridis"
)

# %%
plot.plot_logph_cycles(
    ref=cfg.ref_str,
    t=data["t"],
    cycle_ph=data["cycle_ph"],
    at_time=gs.t_end,
    isotherms=True,
)

plot.plot_logph_cycles(
    ref=cfg.ref_str,
    t=data["t"],
    cycle_ph=data["cycle_ph"],
    t_start=60.0,
    t_end=gs.t_end,
    every_s=60.0,   # alle 60 s ein Kreisprozess
    isotherms=True,
    title="Kreisprozess über die Zeit"
)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['EER'],
              xlabel="Zeit [s]", ylabel="EER",
              title=f"EER", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['COP'],
              xlabel="Zeit [s]", ylabel="COP",
              title=f"COP", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['mean_s_ft'],
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Durchschnittliche Frostdicke", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['m_dot_air'],
              xlabel="Zeit [s]", ylabel="Massenfluss [kg/s]",
              title=f"Gesamter Massenfluss der Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['v_in_air'],
              xlabel="Zeit [s]", ylabel="Geschwindigkeit [m/s]",
              title=f"Geschwindigkeit der Luft am inlet", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_air_mean'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Gemittelte Austrittstemperatur Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_ref'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Austrittstemperatur Kältemittel Verdampfer", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_evap'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Verdampferseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_cond'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Kondenserseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['humidity'],
              xlabel="Zeit [s]", ylabel="Feuchtegehalt [kg/kg]",
              title=f"Feuchtgehalt entlang dem Luftstrom", marker=None,
              labels=["Seg 1","Seg 2","Seg 3","Seg 4","Seg 5"])

# %%
# Segment auswählen
ix, iy = 0, 2

plot_r = int(gs.nr-1)
plot_x = int(gs.nx-1)
plot_theta = int(gs.ntheta-1)
plot_time = int(max(data['t'])/gs.dt)

t, s_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_e", ix, iy)
plot.plot_any(kind="time vs 1D(theta)",
              x=t, y=s_e,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Edge Frostdicke bei θ_idx = {plot_theta} – Segment ({ix},{iy})",
              theta_idx=plot_theta, marker=None)
t, s_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_ft", ix, iy)
plot.plot_any(kind="time vs any",
              x=t, y=s_ft,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"F&T Frostdicke – Segment ({ix},{iy})", marker=None)
t, T_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=T_e,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Edge Frosttemperatur bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, T_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=T_ft,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"F&T Frosttemperatur bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_e,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"Edge Frostdichte bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, rho_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=rho_ft,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"F&T Frostdichte bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_a_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_a_e,
              xlabel="Zeit [s]", ylabel="Dichte der trockenen Luft [kg/m^3]",
              title=f"Edge Dichte der trockenen Luft bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, w_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=w_e,
              xlabel="Zeit [s]", ylabel="w [kg/kg]",
              title=f"Edge Feuchtigkeit bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)

# %%
_, T_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e",      ix, iy)
plot.plot_spatial_slice(
    T_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, T_ft      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft",      ix, iy)
plot.plot_spatial_slice(
    T_ft, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_ft(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, rho_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e",      ix, iy)
plot.plot_spatial_slice(
    rho_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_e [kg/m^3]", marker=None
)
_, w_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e",      ix, iy)
plot.plot_spatial_slice(
    w_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"w_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="w_e [kg/kg]", marker=None
)
_, rho_a_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e",      ix, iy)
plot.plot_spatial_slice(
    rho_a_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_a(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_a [kg/m^3]", marker=None
)
