# %%
from pathlib import Path
import sys
import numpy as np
from CoolProp.HumidAirProp import HAPropsSI
from CoolProp.CoolProp import PropsSI
sys.path.insert(0, str(Path.cwd().parent))
from Framework.core.config import CaseConfig, GridShape, HeatPump
from Framework.core.geometry import FinnTubedHX
from Framework.models import Frostmodell_V1
from Framework.runtime.simulator_V2 import Simulator
from Framework.visualisation import plot
from Framework.runtime.recorder import ResultRecorder

# %% [markdown]
# # Case Definieren

# %%
sim_run = True
read_data = True

#air
T_a = 20.0
P = 101325
RH = 0.5
v_a = 1.2

#refrigerant
w_amb_in = HAPropsSI('W','T',T_a+273.15,'P',P,'R', RH)
rho_amb_in = 1.0 / HAPropsSI("Vha","T",T_a+273.15,"P",P,"R",RH)

refrigerant = "R134a"
#at evaportor
x_in = 0.5
p_ref_in = PropsSI("P", "T", T_a + 273.15, "Q", x_in, refrigerant)
h_ref_in = PropsSI("H", "T", T_a + 273.15, "Q", x_in, refrigerant)

#water
T_in_water = 30.0
N_cond = 12

#at condenser
p_ref_cond = PropsSI("P", "T", T_in_water + 273.15, "Q", x_in, refrigerant)
h_ref_cond = PropsSI("H", "T", T_in_water + 273.15, "Q", x_in, refrigerant)

geom = FinnTubedHX(
    n_seg_l = 2,        # -
    n_seg_r = 10,        # -
    stacks = 4,         # -
    n_fin = 2,           # -
    l_fin = 0.022,          # m
    h_fin = 0.022,          # m
    fin_thickness = 0.0002,    # m
    fin_pitch_cc = 0.0032,          # m
    d_tube_a = 0.00952,          # m
    tube_thickness = 0.0005,       # m
    lambda_fin = 237,            # W/mK
    rho_solid = 2700,            # kg/m3
    c_solid = 900,               # J/kgK
    CP = "row_serpentine"
)

gs = GridShape(
    t_end = 10*60.0,      # s endtime
    dt = 2.0,           # s time step
    store_grid_every_x_it = 10,

    nx = 100,
    nr = 100,
    ntheta = 90,

    #Model Setup
    cal_steady_state = False,
    cal_air = True,
    cal_frost = False,
    cal_ref = True
)

cfg = CaseConfig(
    # air data
    m_dot = v_a*rho_amb_in*(geom.h_fin*geom.fin_gap()*geom.n_seg_r),
    T_a = T_a,          # °C temperature air
    v_a = v_a,          # m/s velocity air
    p_a = P,            # Pa pressure air
    RH = RH,            # relative humidity air
    w_amb = w_amb_in,          # kg/kg water vapor moisture content
    rho_amb = rho_amb_in,      # kg/m^3 density air
    v_kin = 1.5e-5,     # m^2/s kinematic viscosity air
    lam = 0.025,        # W/mK heat conduction coefficient air
    c_p_a = 1000,       # J/kgK heat capacity air
    D_std = 2.2e-5,     # m^2/s water vapor diffusion coefficient
    C = 900,            # 1/s empirical water vapor absorbed coefficient
    isv = 2830000,      # J/kg latent heat of desublimation

    # refrigerant data
    ref_str = refrigerant,
    T_tube = T_a,    # °C tube temperature
    T_ref = T_a,     # °C tube temperature
    p_ref = p_ref_in,      # Pa Kältemitteldruck
    h_ref = h_ref_in,          # J/kg spezifische Enthalpie
    m_dot_ref = 1.0e-4,      # kg/s Massenstrom am Inlet
    m_dot_ref_out = 1.0e-4,      # kg/s Massenstrom am Outlet
    x_ref = x_in,           # Dampfqualität (0..1), NaN falls einphasig

    # ice data
    rho_i = 920,        # kg/m^3 ice density
    h_sub= 2830000,     # J/kg latent heat of ablimation for water vapor
)

HP = HeatPump(
    N_cond=N_cond,
    p_ref_cond = p_ref_cond,
    h_ref_cond = np.full(N_cond, h_ref_cond, dtype=float),
    T_wall = np.full(N_cond, T_in_water, dtype=float),
    T_water = np.full(N_cond, T_in_water, dtype=float),

    A_flow_cond = 0.0005,
    dx_cond = 0.05,
    A_wall = 0.0015,
    A_plate = 0.75,

    #water
    T_in_water = T_in_water,
    m_water = 0.35,
    c_water = 4200,
    rho_water = 997
)

plot.plot_finned_tube_side(geom)
geom.A_one_segment()*geom.n_seg_r*geom.n_seg_l*geom.stacks
# Out:
# 2.2884049669264304

# %% [markdown]
# # Simulation laufen lassen

# %%
result_file = "results_test"

if sim_run:
    sim = Simulator(geom,cfg,HP,result_file)
    results = sim.run(cfg, geom, gs, Frostmodell_V1)
# Out:
# Time Step: 1	 Time: 0.0 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=222, mean T_evap=6.42 °C, mean T_tube_evap=12.21 °C, Q_evap=1789.82 W, Q_cond=0.32 W, ct=170.665 s)
# Cycle time for time step 1: 178.5 s
# Time remaining: 892.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 2	 Time: 2.0 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=17.62 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.34 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.24 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.99 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.10 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.18 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=15.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=15.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=15.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=14.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=13.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=13.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=13.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=13.32 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=13.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=55, mean T_evap=-1.69 °C, mean T_tube_evap=4.59 °C, Q_evap=1207.26 W, Q_cond=2.29 W, ct=36.232 s)
# Cycle time for time step 2: 36.3 s
# Time remaining: 181.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 3	 Time: 4.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.99 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.63 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.93 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.22 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.95 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.42 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=13.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=12.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=6.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=6.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=6.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=6.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=7.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=144, mean T_evap=3.65 °C, mean T_tube_evap=4.26 °C, Q_evap=758.08 W, Q_cond=7.15 W, ct=138.316 s)
# Cycle time for time step 3: 138.4 s
# Time remaining: 687.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 4	 Time: 6.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.63 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.32 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=13.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=13.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=13.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=12.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=12.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=7.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=7.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=8.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=8.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=8.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=49, mean T_evap=5.38 °C, mean T_tube_evap=5.88 °C, Q_evap=634.82 W, Q_cond=14.70 W, ct=42.972 s)
# Cycle time for time step 4: 43.1 s
# Time remaining: 213.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 5	 Time: 8.0 s | 0.1 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.87 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.65 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.52 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.01 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=13.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=13.85 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=13.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=13.49 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=8.18 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=8.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=9.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=9.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=9.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=22, mean T_evap=6.34 °C, mean T_tube_evap=6.90 °C, Q_evap=705.69 W, Q_cond=25.16 W, ct=17.789 s)
# Cycle time for time step 5: 17.9 s
# Time remaining: 88.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 6	 Time: 10.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.80 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.99 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.01 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=13.85 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=9.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=10.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=10.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=10.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=31, mean T_evap=6.34 °C, mean T_tube_evap=6.94 °C, Q_evap=778.14 W, Q_cond=37.67 W, ct=19.912 s)
# Cycle time for time step 6: 20.0 s
# Time remaining: 98.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 7	 Time: 12.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.10 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.97 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.49 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.59 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.32 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=9.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=10.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.82 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=11.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=11.24 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=21, mean T_evap=5.68 °C, mean T_tube_evap=6.40 °C, Q_evap=925.20 W, Q_cond=52.59 W, ct=13.114 s)
# Cycle time for time step 7: 13.2 s
# Time remaining: 64.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 8	 Time: 14.0 s | 0.2 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.15 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.02 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.38 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=15.10 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.97 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=9.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=10.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=10.96 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=11.15 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=47, mean T_evap=4.50 °C, mean T_tube_evap=5.28 °C, Q_evap=1022.96 W, Q_cond=69.19 W, ct=43.418 s)
# Cycle time for time step 8: 43.5 s
# Time remaining: 212.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 9	 Time: 16.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.04 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=17.07 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.23 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.93 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=14.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=14.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=13.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=8.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=9.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=9.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=10.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=10.52 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=41, mean T_evap=2.62 °C, mean T_tube_evap=3.71 °C, Q_evap=1223.74 W, Q_cond=87.59 W, ct=48.530 s)
# Cycle time for time step 9: 48.6 s
# Time remaining: 236.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 10	 Time: 18.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.99 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.81 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=17.01 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=17.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=17.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=14.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=14.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=13.95 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=13.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=12.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=7.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=8.10 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=8.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=9.23 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=9.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=41, mean T_evap=-0.05 °C, mean T_tube_evap=1.54 °C, Q_evap=1370.12 W, Q_cond=107.06 W, ct=34.409 s)
# Cycle time for time step 10: 34.9 s
# Time remaining: 169.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 11	 Time: 20.0 s | 0.3 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.01 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=16.07 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=16.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=16.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.81 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=13.63 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=13.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=13.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=12.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=11.95 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=5.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=6.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=7.01 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=7.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=7.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=52, mean T_evap=-3.53 °C, mean T_tube_evap=-0.81 °C, Q_evap=1548.01 W, Q_cond=127.60 W, ct=63.332 s)
# Cycle time for time step 11: 63.4 s
# Time remaining: 306.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 12	 Time: 22.0 s | 0.4 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=17.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=15.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=15.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=15.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=16.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=16.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=12.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=12.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=11.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=11.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=10.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=2.23 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=3.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=4.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=5.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=5.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=60, mean T_evap=-7.83 °C, mean T_tube_evap=-3.60 °C, Q_evap=1695.27 W, Q_cond=149.04 W, ct=57.047 s)
# Cycle time for time step 12: 57.2 s
# Time remaining: 275.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 13	 Time: 24.0 s | 0.4 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.04 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=17.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=17.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=14.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=14.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=14.93 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=15.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=15.29 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=10.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=10.22 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=9.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=8.95 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=8.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=-1.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=-0.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=0.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=1.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=1.96 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=85, mean T_evap=-13.48 °C, mean T_tube_evap=-6.66 °C, Q_evap=1862.21 W, Q_cond=171.10 W, ct=89.179 s)
# Cycle time for time step 13: 89.3 s
# Time remaining: 428.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 14	 Time: 26.0 s | 0.4 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=17.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=17.45 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=17.07 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=16.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=12.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=12.99 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=13.42 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=13.73 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=13.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=7.81 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=7.34 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=6.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=5.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=4.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=-2.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=-2.81 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=-3.37 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=-3.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=-3.32 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=82, mean T_evap=-20.66 °C, mean T_tube_evap=-10.18 °C, Q_evap=2012.90 W, Q_cond=193.92 W, ct=59.863 s)
# Cycle time for time step 14: 60.0 s
# Time remaining: 286.9 min
# --------------------------------------------------------------------------------------------------
# Time Step: 15	 Time: 28.0 s | 0.5 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=17.37 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=16.96 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=16.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=15.99 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=15.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=9.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=10.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=10.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=11.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=11.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=2.99 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=2.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=1.24 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=0.15 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=0.20 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=-5.32 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=-5.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=-6.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=-7.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=-7.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=99, mean T_evap=-22.63 °C, mean T_tube_evap=-14.03 °C, Q_evap=2172.35 W, Q_cond=217.24 W, ct=81.751 s)
# Cycle time for time step 15: 81.9 s
# Time remaining: 390.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 16	 Time: 30.0 s | 0.5 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=16.10 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=15.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=14.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=13.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=12.99 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=3.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=4.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=5.95 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=6.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=7.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=-4.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=-3.97 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=-3.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=-2.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=-2.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=-10.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=-9.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=-9.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=-8.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=-8.51 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=141, mean T_evap=-21.79 °C, mean T_tube_evap=-18.35 °C, Q_evap=2207.55 W, Q_cond=240.74 W, ct=127.516 s)
# Cycle time for time step 16: 127.6 s
# Time remaining: 606.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 17	 Time: 32.0 s | 0.5 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=12.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=11.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=9.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=7.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=1.63 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=0.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=-0.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=-1.93 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=-2.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=-5.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=-6.32 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=-7.07 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=-7.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=-8.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=-10.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=-11.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=-11.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=-12.10 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=-12.45 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=124, mean T_evap=-21.94 °C, mean T_tube_evap=-20.45 °C, Q_evap=1692.89 W, Q_cond=263.50 W, ct=97.592 s)
# Cycle time for time step 17: 97.7 s
# Time remaining: 462.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 18	 Time: 34.0 s | 0.6 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.04 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=-2.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=-2.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=-2.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=-2.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=-2.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=-8.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=-8.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=-8.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=-8.65 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=-8.65 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=-12.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=-12.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=-12.72 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=-12.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=-12.76 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=44, mean T_evap=-21.33 °C, mean T_tube_evap=-19.92 °C, Q_evap=1604.08 W, Q_cond=284.11 W, ct=20.343 s)
# Cycle time for time step 18: 20.5 s
# Time remaining: 96.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 19	 Time: 36.0 s | 0.6 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=6.59 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=6.59 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=6.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=6.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=6.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=-2.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=-2.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=-2.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=-2.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=-2.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=-8.29 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=-8.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=-8.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=-8.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=-8.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=-12.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=-12.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=-12.34 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=-12.34 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=-12.34 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=115, mean T_evap=-20.99 °C, mean T_tube_evap=-18.28 °C, Q_evap=1232.79 W, Q_cond=303.60 W, ct=142.868 s)
# Cycle time for time step 19: 143.0 s
# Time remaining: 672.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 20	 Time: 38.0 s | 0.6 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=9.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=9.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=8.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=8.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=7.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=-0.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=-0.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=-0.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=-1.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=-1.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=-6.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=-6.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=-7.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=-7.29 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=-7.37 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=-11.15 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=-11.29 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=-11.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=-11.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=-11.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=188, mean T_evap=-14.12 °C, mean T_tube_evap=-13.49 °C, Q_evap=709.12 W, Q_cond=323.40 W, ct=280.866 s)
# Cycle time for time step 20: 281.3 s
# Time remaining: 1317.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 21	 Time: 40.0 s | 0.7 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=12.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=12.52 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=12.10 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=11.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=11.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=4.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=4.49 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=4.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=4.63 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=4.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=-2.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=-2.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=-2.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=-2.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=-2.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=-7.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=-7.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=-7.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=-7.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=-7.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=33, mean T_evap=-6.61 °C, mean T_tube_evap=-6.33 °C, Q_evap=324.16 W, Q_cond=344.22 W, ct=19.683 s)
# Cycle time for time step 21: 19.8 s
# Time remaining: 92.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 22	 Time: 42.0 s | 0.7 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=14.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=14.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=13.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=13.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=13.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=7.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=7.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=7.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=7.85 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=7.80 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=2.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=2.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=2.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=2.07 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=1.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=-2.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=-2.29 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=-2.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=-2.45 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=-2.59 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=25, mean T_evap=0.26 °C, mean T_tube_evap=0.40 °C, Q_evap=162.93 W, Q_cond=366.15 W, ct=11.612 s)
# Cycle time for time step 22: 11.7 s
# Time remaining: 54.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 23	 Time: 44.0 s | 0.7 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=15.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=15.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=15.17 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=14.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=14.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=10.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=10.34 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=10.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=10.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=10.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=6.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=6.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=6.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=5.96 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=5.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=3.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=3.24 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=3.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=2.87 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=2.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=26, mean T_evap=5.18 °C, mean T_tube_evap=5.32 °C, Q_evap=168.03 W, Q_cond=388.95 W, ct=12.772 s)
# Cycle time for time step 23: 12.9 s
# Time remaining: 59.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 24	 Time: 46.0 s | 0.8 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=16.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=16.46 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=16.23 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=15.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=15.72 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=12.62 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=12.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=12.63 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=12.59 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=12.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=9.68 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=9.66 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=9.63 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=9.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=9.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=7.69 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=7.65 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=7.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=7.48 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=7.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=24, mean T_evap=8.18 °C, mean T_tube_evap=8.40 °C, Q_evap=256.20 W, Q_cond=412.39 W, ct=11.631 s)
# Cycle time for time step 24: 11.7 s
# Time remaining: 54.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 25	 Time: 48.0 s | 0.8 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=17.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=17.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=17.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=17.02 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=16.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=14.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=14.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=14.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=14.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=14.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=12.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=12.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=12.27 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=12.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=12.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=10.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=10.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=10.42 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=10.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=10.35 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# ...
# Seg[4,4] | Air(T=33.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=8, mean T_evap=37.24 °C, mean T_tube_evap=36.45 °C, Q_evap=-863.27 W, Q_cond=2438.44 W, ct=8.642 s)
# Cycle time for time step 293: 8.8 s
# Time remaining: 1.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 294	 Time: 586.0 s | 9.8 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=22.37 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=22.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=22.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=23.02 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=23.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=26.18 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=26.02 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=25.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=25.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=25.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=29.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=29.23 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=29.42 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=29.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=29.97 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=33.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=33.56 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=33.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=33.23 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=33.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=9, mean T_evap=37.29 °C, mean T_tube_evap=36.49 °C, Q_evap=-865.50 W, Q_cond=2439.84 W, ct=1.630 s)
# Cycle time for time step 294: 1.7 s
# Time remaining: 0.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 295	 Time: 588.0 s | 9.8 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=22.37 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=22.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=22.79 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=23.03 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=23.29 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=26.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=26.04 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=25.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=25.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=25.80 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=29.11 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=29.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=29.45 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=29.70 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=30.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=33.87 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=33.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=33.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=33.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=33.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=7, mean T_evap=37.33 °C, mean T_tube_evap=36.54 °C, Q_evap=-867.69 W, Q_cond=2441.24 W, ct=8.322 s)
# Cycle time for time step 295: 8.4 s
# Time remaining: 0.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 296	 Time: 590.0 s | 9.8 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=22.38 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=22.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=22.80 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=23.04 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=23.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=26.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=26.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=25.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=25.86 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=25.82 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=29.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=29.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=29.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=29.72 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=30.02 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=33.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=33.64 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=33.43 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=33.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=33.23 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=4, mean T_evap=37.38 °C, mean T_tube_evap=36.58 °C, Q_evap=-869.84 W, Q_cond=2442.62 W, ct=7.997 s)
# Cycle time for time step 296: 8.1 s
# Time remaining: 0.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 297	 Time: 592.0 s | 9.9 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=22.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=22.59 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=22.81 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=23.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=23.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=26.23 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=26.07 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=25.95 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=25.88 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=25.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=29.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=29.31 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=29.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=29.75 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=30.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=33.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=33.67 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=33.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=33.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=33.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=5, mean T_evap=37.42 °C, mean T_tube_evap=36.62 °C, Q_evap=-872.03 W, Q_cond=2444.00 W, ct=15.921 s)
# Cycle time for time step 297: 16.0 s
# Time remaining: 1.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 298	 Time: 594.0 s | 9.9 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=22.39 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=22.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=22.82 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=23.06 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=23.32 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=26.25 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=26.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=25.97 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=25.89 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=25.85 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=29.19 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=29.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=29.53 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=29.77 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=30.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=33.98 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=33.71 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=33.50 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=33.37 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=33.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=4, mean T_evap=37.47 °C, mean T_tube_evap=36.67 °C, Q_evap=-874.19 W, Q_cond=2445.37 W, ct=0.660 s)
# Cycle time for time step 298: 0.8 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 299	 Time: 596.0 s | 9.9 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=22.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=22.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=22.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=23.07 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=23.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=26.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=26.10 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=25.99 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=25.91 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=25.87 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=29.21 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=29.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=29.55 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=29.80 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=30.10 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=34.02 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=33.74 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=33.54 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=33.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=33.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=5, mean T_evap=37.51 °C, mean T_tube_evap=36.71 °C, Q_evap=-876.37 W, Q_cond=2446.73 W, ct=15.770 s)
# Cycle time for time step 299: 15.9 s
# Time remaining: 0.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 300	 Time: 598.0 s | 10.0 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=22.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=22.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=22.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=23.07 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=23.33 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=26.28 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=26.12 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=26.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=25.92 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=25.88 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=29.23 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=29.38 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=29.58 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=29.83 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=30.13 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=34.05 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=33.78 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=33.57 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=33.44 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=33.36 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=5, mean T_evap=37.56 °C, mean T_tube_evap=36.75 °C, Q_evap=-878.53 W, Q_cond=2448.08 W, ct=0.836 s)
# Cycle time for time step 300: 1.3 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 301	 Time: 600.0 s | 10.0 min
# Seg[0,0] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=22.41 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=22.62 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=22.84 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=23.08 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=23.34 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,0] | Air(T=26.30 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,1] | Air(T=26.14 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,2] | Air(T=26.02 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,3] | Air(T=25.94 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[2,4] | Air(T=25.90 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,0] | Air(T=29.26 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,1] | Air(T=29.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,2] | Air(T=29.60 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,3] | Air(T=29.85 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[3,4] | Air(T=30.16 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,0] | Air(T=34.09 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,1] | Air(T=33.81 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,2] | Air(T=33.61 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,3] | Air(T=33.47 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Seg[4,4] | Air(T=33.40 °C, w=7.294e-03 kg/kg, P=1.013e+05 Pa)
# Pushing grid state
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=5, mean T_evap=37.60 °C, mean T_tube_evap=36.79 °C, Q_evap=-880.68 W, Q_cond=2449.42 W, ct=0.860 s)
# Cycle time for time step 301: 1.3 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Simulation ended at 2025-12-21 19:50:15
# Time to complete: 58.0 min

# %% [markdown]
# # Resultate speichen/laden

# %%
if sim_run:
    data = results.data
    results.to_csv(result_file,data)

if read_data:
    data = ResultRecorder.read_results_csv_json(result_file)
    results = ResultRecorder.from_jsonl(result_file)

# %% [markdown]
# # Resultate plotten

# %%
snapshots = results.grid_snapshots

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="v_a",
    source="cfg",
    t_idx=-1,          # letzter Zeitschritt
    title="Geschwindigkeit der Luft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="s_ft",
    source="st",       # aus SimState
    t_idx=-1,          # letzter Zeitschritt
    title="Frostdicke s_ft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_a",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Lufttemperatur T_a über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="w_amb",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="RH",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="relative Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_tube",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur der Wände über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur des Kältemittels über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="h_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Enthalpie des Kältemittels über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="p_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Druck vom Kältemittel über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="x_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="X des Kältemittel über alle Segmente",
    cmap="viridis"
)

# %%
plot.plot_any(kind="time vs any",
              x=data['t'], y=data['COP_cold'],
              xlabel="Zeit [s]", ylabel="COP",
              title=f"COP Kalt", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['COP_warm'],
              xlabel="Zeit [s]", ylabel="COP",
              title=f"COP Warm", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['mean_s_ft'],
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Durchschnittliche Frostdicke", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_air_mean'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Gemittelte Austrittstemperatur Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_ref'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Austrittstemperatur Kältemittel", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['humidity'],
              xlabel="Zeit [s]", ylabel="Feuchtegehalt [kg/kg]",
              title=f"Feuchtgehalt entlang dem Luftstrom", marker=None,
              labels=["Seg 1","Seg 2","Seg 3","Seg 4","Seg 5"])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Feuchtgehalt entlang dem Luftstrom'}, xlabel='Zeit [s]', ylabel='Feuchtegehalt [kg/kg]'>)

# %%
# Segment auswählen
ix, iy = 0, 2

plot_r = int(gs.nr-1)
plot_x = int(gs.nx-1)
plot_theta = int(gs.ntheta-1)
plot_time = int(max(data['t'])/gs.dt)

t, s_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_e", ix, iy)
plot.plot_any(kind="time vs 1D(theta)",
              x=t, y=s_e,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Edge Frostdicke bei θ_idx = {plot_theta} – Segment ({ix},{iy})",
              theta_idx=plot_theta, marker=None)
t, s_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_ft", ix, iy)
plot.plot_any(kind="time vs any",
              x=t, y=s_ft,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"F&T Frostdicke – Segment ({ix},{iy})", marker=None)
t, T_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=T_e,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Edge Frosttemperatur bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, T_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=T_ft,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"F&T Frosttemperatur bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_e,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"Edge Frostdichte bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, rho_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=rho_ft,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"F&T Frostdichte bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_a_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_a_e,
              xlabel="Zeit [s]", ylabel="Dichte der trockenen Luft [kg/m^3]",
              title=f"Edge Dichte der trockenen Luft bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, w_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=w_e,
              xlabel="Zeit [s]", ylabel="w [kg/kg]",
              title=f"Edge Feuchtigkeit bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\OneDrive\Dokumente\GitHub\MSE_VT1_luethluk\Framework\visualisation\plot.py:42, in extract_segment_timeseries_from_snapshots(grid_snapshots, field, ix, iy)
#      41 try:
# ---> 42     val = getattr(st_ij, field)
#      43 except AttributeError as e:
#
# AttributeError: 'SimState' object has no attribute 'rho_a_e'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 44
#      38 t, rho_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_ft", ix, iy)
#      39 plot.plot_any(kind="time vs 1D(r)",
#      40               x=t, y=rho_ft,
#      41               xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
#      42               title=f"F&T Frostdichte bei x_idx = {plot_x} – Segment ({ix},{iy})",
#      43               r_idx=plot_x, marker=None)
# ---> 44 t, rho_a_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e", ix, iy)
#      45 plot.plot_any(kind="time vs 2D(r,theta)",
#      46               x=t, y=rho_a_e,
#      47               xlabel="Zeit [s]", ylabel="Dichte der trockenen Luft [kg/m^3]",
#      48               title=f"Edge Dichte der trockenen Luft bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
#      49               r_idx=plot_r, theta_idx=plot_theta, marker=None)
#      50 t, w_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e", ix, iy)
#
# File ~\OneDrive\Dokumente\GitHub\MSE_VT1_luethluk\Framework\visualisation\plot.py:44, in extract_segment_timeseries_from_snapshots(grid_snapshots, field, ix, iy)
#      42     val = getattr(st_ij, field)
#      43 except AttributeError as e:
# ---> 44     raise AttributeError(
#      45         f"SimState hat kein Attribut '{field}'. "
#      46         f"Verfügbare: {list(vars(st_ij).keys())}"
#      47     ) from e
#      49 # in Array wandeln (damit Shapes vergleichbar sind)
#      50 y_list.append(np.asarray(val))
#
# AttributeError: SimState hat kein Attribut 'rho_a_e'. Verfügbare: ['t', 's_e', 'T_e', 'rho_e', 'rho_a', 'w_e', 's_ft', 'T_ft', 'rho_ft', 'w_ft']

# %%
_, T_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e",      ix, iy)
plot.plot_spatial_slice(
    T_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, T_ft      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft",      ix, iy)
plot.plot_spatial_slice(
    T_ft, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_ft(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, rho_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e",      ix, iy)
plot.plot_spatial_slice(
    rho_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_e [kg/m^3]", marker=None
)
_, w_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e",      ix, iy)
plot.plot_spatial_slice(
    w_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"w_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="w_e [kg/kg]", marker=None
)
_, rho_a_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e",      ix, iy)
plot.plot_spatial_slice(
    rho_a_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_a(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_a [kg/m^3]", marker=None
)
