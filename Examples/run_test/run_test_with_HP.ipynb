# %%
from pathlib import Path
import sys
import numpy as np
from CoolProp.HumidAirProp import HAPropsSI
from CoolProp.CoolProp import PropsSI
sys.path.insert(0, str(Path.cwd().parents[1]))
from Framework.core.config import CaseConfig, GridShape, HeatPump
from Framework.core.geometry import FinnTubedHX
from Framework.models import Frostmodell_V1
from Framework.runtime.simulator_V2 import Simulator
from Framework.visualisation import plot
from Framework.runtime.recorder import ResultRecorder

# %% [markdown]
# # Case Definieren

# %%
sim_run = True
read_data = True

#air
T_a = 20.0
P = 101325
RH = 0.1
v_a = 1.2

#water
T_in_water = 40.0
N_cond = 22

#refrigerant
w_amb_in = HAPropsSI('W','T',T_a+273.15,'P',P,'R', RH)
rho_amb_in = 1.0 / HAPropsSI("Vha","T",T_a+273.15,"P",P,"R",RH)

refrigerant = "R134a"
#at evaportor
x_evap = 0.5
p_ref_evap = PropsSI("P", "T", T_a + 273.15, "Q", x_evap, refrigerant)
h_ref_evap = PropsSI("H", "T", T_a + 273.15, "Q", x_evap, refrigerant)

#at condenser
x_cond = 0.5
p_ref_cond = PropsSI("P", "T", T_in_water + 273.15, "Q", x_cond, refrigerant)
h_ref_cond = PropsSI("H", "T", T_in_water + 273.15, "Q", x_cond, refrigerant)

geom = FinnTubedHX(
    n_seg_l = 2,        # -
    n_seg_r = 20,        # -
    stacks = 150,         # -
    n_fin = 2,           # -
    l_fin = 0.022,          # m
    h_fin = 0.022,          # m
    fin_thickness = 0.0002,    # m
    fin_pitch_cc = 0.0032,          # m
    d_tube_a = 0.00952,          # m
    tube_thickness = 0.0005,       # m
    lambda_fin = 237,            # W/mK
    rho_solid = 2700,            # kg/m3
    c_solid = 900,               # J/kgK
    CP = "row_serpentine"
)

gs = GridShape(
    t_end = 10*60.0,      # s endtime
    dt = 0.1,           # s time step
    store_grid_every_x_it = 50,

    nx = 100,
    nr = 100,
    ntheta = 90,

    #Model Setup
    cal_steady_state = False,
    cal_air = True,
    cal_frost = False,
    cal_ref = True
)

cfg = CaseConfig(
    # air data
    m_dot = v_a*rho_amb_in*(geom.h_fin*geom.fin_gap()*geom.n_seg_r*geom.stacks), # Backup massflow if no fan is used
    T_a = T_a,          # °C temperature air
    v_a = v_a,          # m/s velocity air
    p_a = P,            # Pa pressure air
    RH = RH,            # relative humidity air
    w_amb = w_amb_in,          # kg/kg water vapor moisture content
    rho_amb = rho_amb_in,      # kg/m^3 density air
    v_kin = 1.5e-5,     # m^2/s kinematic viscosity air
    lam = 0.025,        # W/mK heat conduction coefficient air
    c_p_a = 1000,       # J/kgK heat capacity air
    D_std = 2.2e-5,     # m^2/s water vapor diffusion coefficient
    C = 900,            # 1/s empirical water vapor absorbed coefficient
    isv = 2830000,      # J/kg latent heat of desublimation

    # fan model
    use_fan = True,
    fan_dp0 = 150.0,
    fan_V0 = v_a*(geom.h_fin*geom.fin_gap()*geom.n_seg_r*geom.stacks),
    dp_clean = 40.0,


    # refrigerant data
    ref_str = refrigerant,
    T_tube = T_a,    # °C tube temperature
    T_ref = T_a,     # °C tube temperature
    p_ref = p_ref_evap,      # Pa Kältemitteldruck
    h_ref = h_ref_evap,          # J/kg spezifische Enthalpie
    m_dot_ref = 0,      # kg/s Massenstrom am Inlet (invalid)
    m_dot_ref_out = 0,      # kg/s Massenstrom am Outlet (invalid)
    x_ref = float("nan"),           # Dampfqualität (0..1), NaN falls einphasig

    # ice data
    rho_i = 920,        # kg/m^3 ice density
    h_sub= 2830000,     # J/kg latent heat of ablimation for water vapor
)

HP = HeatPump(
    N_cond=N_cond,
    p_ref_cond = p_ref_cond,
    h_ref_cond = np.full(N_cond, h_ref_cond, dtype=float),
    T_wall = np.full(N_cond, T_in_water, dtype=float),
    T_water = np.full(N_cond, T_in_water, dtype=float),

    A_flow_cond = 0.01,
    dx_cond = 0.5/N_cond,
    t_plate = 0.001,
    height_cond=1.0,
    A_plate = 3.65,
    c_plate = 500,
    rho_plate = 8000.0,
    lamda_plate = 50.0,

    #water
    T_in_water = T_in_water,
    m_water = 0.5,
    c_water = 4200,
    rho_water = 997
)

plot.plot_finned_tube_side(geom)
print(f"Surface area Evaporator = {geom.A_one_segment()*geom.n_seg_r*geom.n_seg_l*geom.stacks:.2f} m2")
print(f"Surface area Condenser = {HP.A_plate:.2f} m2")
# Out:
# Surface area Evaporator = 5.49 m2
# Surface area Condenser = 3.65 m2

# %% [markdown]
# # Simulation laufen lassen

# %%
result_file = "results_test"

if sim_run:
    sim = Simulator(geom,cfg,HP,result_file)
    results = sim.run(cfg, geom, gs, Frostmodell_V1)
# Out:
# Time Step: 1	 Time: 0.00 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=11, evap_out=TP(x=0.500, Tsat=20.01°C, T=20.01°C), cond_out=TP(x=0.500, Tsat=40.00°C, T=40.00°C), Q_evap=-15.41 W, Q_cond=-15.86 W, ct=0.165 s)
# Updating dt for the next time step to dt=0.10 s
# Cycle time for time step 1: 0.7 s
# Time remaining: 75.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 2	 Time: 0.10 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=6, evap_out=TP(x=0.502, Tsat=19.92°C, T=19.92°C), cond_out=TP(x=0.500, Tsat=40.01°C, T=40.01°C), Q_evap=197.97 W, Q_cond=30.95 W, ct=0.070 s)
# Updating dt for the next time step to dt=0.12 s
# Cycle time for time step 2: 0.3 s
# Time remaining: 21.2 min
# --------------------------------------------------------------------------------------------------
# Time Step: 3	 Time: 0.20 s | 0.0 min
# Seg[0,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=20.00 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=5, evap_out=TP(x=0.507, Tsat=19.74°C, T=19.74°C), cond_out=TP(x=0.499, Tsat=40.04°C, T=40.04°C), Q_evap=532.05 W, Q_cond=183.07 W, ct=0.091 s)
# Updating dt for the next time step to dt=0.17 s
# Cycle time for time step 3: 0.3 s
# Time remaining: 14.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 4	 Time: 0.32 s | 0.0 min
# Seg[0,0] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=19.98 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.96 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=7, evap_out=TP(x=0.522, Tsat=19.37°C, T=19.37°C), cond_out=TP(x=0.498, Tsat=40.08°C, T=40.08°C), Q_evap=1017.32 W, Q_cond=504.55 W, ct=1.023 s)
# Updating dt for the next time step to dt=0.21 s
# Cycle time for time step 4: 1.2 s
# Time remaining: 56.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 5	 Time: 0.49 s | 0.0 min
# Seg[0,0] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=19.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.85 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=9, evap_out=TP(x=0.550, Tsat=18.78°C, T=18.78°C), cond_out=TP(x=0.495, Tsat=40.15°C, T=40.15°C), Q_evap=1590.62 W, Q_cond=967.95 W, ct=0.998 s)
# Updating dt for the next time step to dt=0.22 s
# Cycle time for time step 5: 1.2 s
# Time remaining: 54.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 6	 Time: 0.70 s | 0.0 min
# Seg[0,0] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=19.77 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.63 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=8, evap_out=TP(x=0.595, Tsat=18.01°C, T=18.01°C), cond_out=TP(x=0.490, Tsat=40.23°C, T=40.23°C), Q_evap=2180.24 W, Q_cond=1493.07 W, ct=1.126 s)
# Updating dt for the next time step to dt=0.25 s
# Cycle time for time step 6: 1.3 s
# Time remaining: 53.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 7	 Time: 0.92 s | 0.0 min
# Seg[0,0] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=19.58 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=19.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=9, evap_out=TP(x=0.668, Tsat=16.97°C, T=16.97°C), cond_out=TP(x=0.484, Tsat=40.33°C, T=40.33°C), Q_evap=2809.52 W, Q_cond=2096.42 W, ct=0.190 s)
# Updating dt for the next time step to dt=0.26 s
# Cycle time for time step 7: 0.3 s
# Time remaining: 13.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 8	 Time: 1.17 s | 0.0 min
# Seg[0,0] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=19.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.83 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=13, evap_out=TP(x=0.779, Tsat=15.71°C, T=15.71°C), cond_out=TP(x=0.484, Tsat=40.44°C, T=40.44°C), Q_evap=3429.80 W, Q_cond=2736.14 W, ct=1.206 s)
# Updating dt for the next time step to dt=0.23 s
# Cycle time for time step 8: 1.4 s
# Time remaining: 61.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 9	 Time: 1.42 s | 0.0 min
# Seg[0,0] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=18.93 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=11, evap_out=TP(x=0.915, Tsat=14.49°C, T=14.49°C), cond_out=TP(x=0.505, Tsat=40.54°C, T=40.54°C), Q_evap=3930.60 W, Q_cond=3291.73 W, ct=1.804 s)
# Updating dt for the next time step to dt=0.22 s
# Cycle time for time step 9: 1.9 s
# Time remaining: 89.7 min
# --------------------------------------------------------------------------------------------------
# Time Step: 10	 Time: 1.65 s | 0.0 min
# Seg[0,0] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=18.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=17.62 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=90, evap_out=SH=2.49K (Tsat=11.48°C, T=13.97°C), cond_out=TP(x=0.559, Tsat=40.63°C, T=40.63°C), Q_evap=1278.89 W, Q_cond=3773.94 W, ct=8.416 s)
# Updating dt for the next time step to dt=0.11 s
# Cycle time for time step 10: 8.6 s
# Time remaining: 790.1 min
# --------------------------------------------------------------------------------------------------
# Time Step: 11	 Time: 1.87 s | 0.0 min
# Seg[0,0] | Air(T=18.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=18.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=18.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=18.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=18.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=18.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=18.46 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=18.32 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=18.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=18.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=18.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=18.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=18.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=18.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=18.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=18.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=18.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=18.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=18.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=18.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=17.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=17.20 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=17.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=17.20 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=17.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=17.21 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=17.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=17.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=17.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=17.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=17.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=17.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=17.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=17.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=17.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.14 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=17.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=17.02 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=16.92 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=36, evap_out=SH=5.63K (Tsat=8.82°C, T=14.46°C), cond_out=TP(x=0.594, Tsat=40.66°C, T=40.66°C), Q_evap=992.55 W, Q_cond=3887.25 W, ct=4.450 s)
# Updating dt for the next time step to dt=0.06 s
# Cycle time for time step 11: 4.8 s
# Time remaining: 832.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 12	 Time: 1.97 s | 0.0 min
# Seg[0,0] | Air(T=18.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=18.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=18.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=18.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=18.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=18.32 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=18.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=18.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=18.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=18.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=18.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=18.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=18.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=18.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=18.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=18.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=18.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=18.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=18.17 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=17.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=17.22 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=17.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=17.22 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=17.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=17.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=17.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=17.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=17.32 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=17.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=17.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=17.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=17.32 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=17.32 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=17.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.14 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=16.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=16.61 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=16.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=9, evap_out=SH=7.32K (Tsat=7.35°C, T=14.68°C), cond_out=TP(x=0.614, Tsat=40.66°C, T=40.66°C), Q_evap=937.64 W, Q_cond=3904.12 W, ct=0.192 s)
# Updating dt for the next time step to dt=0.06 s
# Cycle time for time step 12: 0.4 s
# Time remaining: 63.4 min
# --------------------------------------------------------------------------------------------------
# Time Step: 13	 Time: 2.03 s | 0.0 min
# Seg[0,0] | Air(T=18.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=18.32 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=18.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=18.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=18.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=18.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=18.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=18.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=18.45 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=18.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=18.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=18.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=18.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=18.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=18.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=18.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=18.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=18.18 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=17.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=17.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=17.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=17.23 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=17.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=17.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=17.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=17.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=17.32 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=17.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=17.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=17.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=17.32 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=17.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=17.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.14 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=16.90 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=16.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=16.06 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=18, evap_out=SH=9.13K (Tsat=5.76°C, T=14.89°C), cond_out=TP(x=0.637, Tsat=40.67°C, T=40.67°C), Q_evap=778.71 W, Q_cond=3894.53 W, ct=2.072 s)
# Updating dt for the next time step to dt=0.04 s
# Cycle time for time step 13: 2.2 s
# Time remaining: 497.6 min
# --------------------------------------------------------------------------------------------------
# Time Step: 14	 Time: 2.09 s | 0.0 min
# Seg[0,0] | Air(T=18.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=18.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=18.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=18.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=18.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=18.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=18.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=18.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=18.45 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=18.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=18.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=18.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=18.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=18.20 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=17.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=17.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=17.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=17.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=17.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=17.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=17.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=17.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=17.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=17.29 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=17.32 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=17.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=17.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=17.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=17.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=16.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=16.55 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=15.80 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=6, evap_out=SH=10.38K (Tsat=4.56°C, T=14.94°C), cond_out=TP(x=0.655, Tsat=40.67°C, T=40.67°C), Q_evap=744.64 W, Q_cond=3871.12 W, ct=0.080 s)
# Updating dt for the next time step to dt=0.06 s
# Cycle time for time step 14: 0.2 s
# Time remaining: 41.3 min
# --------------------------------------------------------------------------------------------------
# Time Step: 15	 Time: 2.14 s | 0.0 min
# Seg[0,0] | Air(T=18.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=18.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=18.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=18.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=18.51 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=18.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=18.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=18.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=18.46 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=18.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=18.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=18.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=18.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=18.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=18.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=18.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=18.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=18.22 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=17.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=17.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=17.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=17.26 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=17.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=17.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=17.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=17.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=17.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=17.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=17.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=17.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=17.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=17.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=17.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.16 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=16.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=16.55 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=15.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=3, evap_out=SH=12.00K (Tsat=3.00°C, T=15.01°C), cond_out=TP(x=0.679, Tsat=40.67°C, T=40.67°C), Q_evap=700.14 W, Q_cond=3822.97 W, ct=0.030 s)
# Updating dt for the next time step to dt=0.11 s
# Cycle time for time step 15: 0.2 s
# Time remaining: 16.8 min
# --------------------------------------------------------------------------------------------------
# Time Step: 16	 Time: 2.19 s | 0.0 min
# Seg[0,0] | Air(T=18.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=18.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=18.53 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=18.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=18.51 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=18.38 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=18.48 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=18.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=18.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=18.42 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=18.45 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=18.43 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=18.45 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=18.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=18.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=18.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=18.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=18.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=18.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=18.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=17.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=17.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=17.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=17.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=17.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=17.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=17.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=17.30 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=17.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=17.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=17.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=17.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=17.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=17.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=17.37 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=17.31 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=17.17 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=16.92 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=16.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=15.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=4, evap_out=SH=14.94K (Tsat=0.19°C, T=15.13°C), cond_out=TP(x=0.725, Tsat=40.67°C, T=40.67°C), Q_evap=617.55 W, Q_cond=3692.68 W, ct=0.839 s)
# Updating dt for the next time step to dt=0.17 s
# Cycle time for time step 16: 1.0 s
# Time remaining: 59.5 min
# --------------------------------------------------------------------------------------------------
# Time Step: 17	 Time: 2.30 s | 0.0 min
# Seg[0,0] | Air(T=18.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=18.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=18.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=18.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=18.52 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=18.41 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=18.50 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# ...
# Seg[1,10] | Air(T=-7.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-7.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-7.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-7.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-7.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-7.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-7.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-7.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-7.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-7.20 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=2, evap_out=SH=27.12K (Tsat=-26.13°C, T=0.99°C), cond_out=TP(x=0.346, Tsat=42.80°C, T=42.80°C), Q_evap=2953.18 W, Q_cond=5744.24 W, ct=0.027 s)
# Updating dt for the next time step to dt=5.00 s
# Cycle time for time step 689: 0.3 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 690	 Time: 575.62 s | 9.6 min
# Seg[0,0] | Air(T=-5.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=-4.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=-3.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=-2.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=-1.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=-1.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=-0.68 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=-0.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=0.06 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=0.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=0.59 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=0.80 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=0.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=1.13 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=1.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=1.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=1.46 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=1.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=1.61 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=1.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-10.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-10.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-10.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-9.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-9.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-9.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-8.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-8.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-8.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-8.08 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-7.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-7.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-7.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-7.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-7.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-7.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-7.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-7.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-7.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-7.20 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=2, evap_out=SH=27.12K (Tsat=-26.13°C, T=0.99°C), cond_out=TP(x=0.346, Tsat=42.80°C, T=42.80°C), Q_evap=2953.18 W, Q_cond=5744.24 W, ct=0.026 s)
# Updating dt for the next time step to dt=5.00 s
# Cycle time for time step 690: 0.3 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 691	 Time: 580.62 s | 9.7 min
# Seg[0,0] | Air(T=-5.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=-4.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=-3.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=-2.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=-1.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=-1.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=-0.68 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=-0.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=0.06 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=0.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=0.59 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=0.80 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=0.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=1.13 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=1.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=1.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=1.46 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=1.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=1.61 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=1.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-10.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-10.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-10.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-9.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-9.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-9.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-8.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-8.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-8.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-8.08 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-7.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-7.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-7.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-7.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-7.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-7.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-7.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-7.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-7.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-7.20 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=2, evap_out=SH=27.12K (Tsat=-26.13°C, T=0.99°C), cond_out=TP(x=0.346, Tsat=42.80°C, T=42.80°C), Q_evap=2953.18 W, Q_cond=5744.24 W, ct=0.038 s)
# Updating dt for the next time step to dt=5.00 s
# Cycle time for time step 691: 0.3 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 692	 Time: 585.62 s | 9.8 min
# Seg[0,0] | Air(T=-5.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=-4.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=-3.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=-2.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=-1.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=-1.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=-0.68 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=-0.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=0.06 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=0.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=0.59 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=0.80 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=0.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=1.13 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=1.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=1.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=1.46 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=1.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=1.61 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=1.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-10.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-10.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-10.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-9.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-9.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-9.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-8.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-8.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-8.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-8.08 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-7.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-7.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-7.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-7.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-7.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-7.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-7.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-7.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-7.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-7.20 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=2, evap_out=SH=27.12K (Tsat=-26.13°C, T=0.99°C), cond_out=TP(x=0.346, Tsat=42.80°C, T=42.80°C), Q_evap=2953.18 W, Q_cond=5744.24 W, ct=0.029 s)
# Updating dt for the next time step to dt=5.00 s
# Cycle time for time step 692: 0.3 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 693	 Time: 590.62 s | 9.8 min
# Seg[0,0] | Air(T=-5.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=-4.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=-3.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=-2.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=-1.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=-1.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=-0.68 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=-0.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=0.06 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=0.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=0.59 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=0.80 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=0.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=1.13 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=1.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=1.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=1.46 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=1.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=1.61 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=1.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-10.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-10.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-10.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-9.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-9.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-9.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-8.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-8.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-8.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-8.08 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-7.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-7.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-7.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-7.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-7.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-7.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-7.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-7.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-7.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-7.20 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=2, evap_out=SH=27.12K (Tsat=-26.13°C, T=0.99°C), cond_out=TP(x=0.346, Tsat=42.80°C, T=42.80°C), Q_evap=2953.18 W, Q_cond=5744.24 W, ct=0.025 s)
# Updating dt for the next time step to dt=5.00 s
# Cycle time for time step 693: 0.3 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Time Step: 694	 Time: 595.62 s | 9.9 min
# Seg[0,0] | Air(T=-5.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,1] | Air(T=-4.01 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,2] | Air(T=-3.11 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,3] | Air(T=-2.35 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,4] | Air(T=-1.70 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,5] | Air(T=-1.15 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,6] | Air(T=-0.68 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,7] | Air(T=-0.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,8] | Air(T=0.06 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,9] | Air(T=0.34 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,10] | Air(T=0.59 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,11] | Air(T=0.80 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,12] | Air(T=0.97 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,13] | Air(T=1.13 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,14] | Air(T=1.25 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,15] | Air(T=1.36 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,16] | Air(T=1.46 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,17] | Air(T=1.54 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,18] | Air(T=1.61 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[0,19] | Air(T=1.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,0] | Air(T=-10.74 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,1] | Air(T=-10.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,2] | Air(T=-10.39 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,3] | Air(T=-9.88 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,4] | Air(T=-9.44 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,5] | Air(T=-9.07 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,6] | Air(T=-8.76 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,7] | Air(T=-8.49 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,8] | Air(T=-8.27 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,9] | Air(T=-8.08 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,10] | Air(T=-7.91 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,11] | Air(T=-7.78 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,12] | Air(T=-7.66 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,13] | Air(T=-7.56 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,14] | Air(T=-7.47 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,15] | Air(T=-7.40 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,16] | Air(T=-7.33 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,17] | Air(T=-7.28 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,18] | Air(T=-7.24 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Seg[1,19] | Air(T=-7.20 °C, w=1.445e-03 kg/kg, P=1.013e+05 Pa)
# Calculating the refrigerant state for the next time step in all segments...
# HP(it=2, evap_out=SH=27.12K (Tsat=-26.13°C, T=0.99°C), cond_out=TP(x=0.346, Tsat=42.80°C, T=42.80°C), Q_evap=2953.18 W, Q_cond=5744.24 W, ct=0.033 s)
# Updating dt for the next time step to dt=5.00 s
# Cycle time for time step 694: 0.3 s
# Time remaining: 0.0 min
# --------------------------------------------------------------------------------------------------
# Simulation ended at 2026-01-05 17:34:05
# Time to complete: 16.8 min

# %% [markdown]
# # Resultate speichen/laden

# %%
if sim_run:
    data = results.data
    results.to_csv(result_file,data)

if read_data:
    data = ResultRecorder.read_results_csv_json(result_file)
    results = ResultRecorder.from_jsonl(result_file)

# %% [markdown]
# # Resultate plotten

# %%
snapshots = results.grid_snapshots

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="v_a",
    source="cfg",
    t_idx=-1,          # letzter Zeitschritt
    title="Geschwindigkeit der Luft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_sft = plot.plot_segment_field_grid(
    snapshots,
    field="s_ft",
    source="st",       # aus SimState
    t_idx=-1,          # letzter Zeitschritt
    title="Frostdicke s_ft über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_a",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Lufttemperatur T_a über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="w_amb",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="RH",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="relative Feuchtigkeit der Luft w_amb über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_tube",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur der Wände über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="T_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Temperatur des Kältemittels über alle Segmente",
    cmap="plasma"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="h_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Enthalpie des Kältemittels über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="p_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="Druck vom Kältemittel über alle Segmente",
    cmap="viridis"
)

fig, ax, Z_Ta = plot.plot_segment_field_grid(
    snapshots,
    field="x_ref",
    source="cfg",      # aus CaseConfig
    t_idx=-1,
    title="X des Kältemittel über alle Segmente",
    cmap="viridis"
)

# %%
plot.plot_logph_cycles(
    ref=cfg.ref_str,
    t=data["t"],
    cycle_ph=data["cycle_ph"],
    at_time=gs.t_end,
    isotherms=True,
)

plot.plot_logph_cycles(
    ref=cfg.ref_str,
    t=data["t"],
    cycle_ph=data["cycle_ph"],
    t_start=60.0,
    t_end=gs.t_end,
    every_s=60.0,   # alle x s ein Kreisprozess
    isotherms=True,
    title="Kreisprozess über die Zeit"
)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['EER'],
              xlabel="Zeit [s]", ylabel="EER",
              title=f"EER", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['COP'],
              xlabel="Zeit [s]", ylabel="COP",
              title=f"COP", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['mean_s_ft'],
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Durchschnittliche Frostdicke", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['m_dot_air'],
              xlabel="Zeit [s]", ylabel="Massenfluss [kg/s]",
              title=f"Gesamter Massenfluss der Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['v_in_air'],
              xlabel="Zeit [s]", ylabel="Geschwindigkeit [m/s]",
              title=f"Geschwindigkeit der Luft am inlet", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_air_mean'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Gemittelte Austrittstemperatur Luft", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['T_out_ref'],
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Austrittstemperatur Kältemittel Verdampfer", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_evap'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Verdampferseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['p_ref_cond'],
              xlabel="Zeit [s]", ylabel="Druck [Pa]",
              title=f"Druck des Kältemittels Kondenserseite", marker=None)

plot.plot_any(kind="time vs any",
              x=data['t'], y=data['humidity'],
              xlabel="Zeit [s]", ylabel="Feuchtegehalt [kg/kg]",
              title=f"Feuchtgehalt entlang dem Luftstrom", marker=None,
              labels=["Seg 1","Seg 2","Seg 3","Seg 4","Seg 5"])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Feuchtgehalt entlang dem Luftstrom'}, xlabel='Zeit [s]', ylabel='Feuchtegehalt [kg/kg]'>)

# %%
# Segment auswählen
ix, iy = 0, 2

plot_r = int(gs.nr-1)
plot_x = int(gs.nx-1)
plot_theta = int(gs.ntheta-1)
plot_time = int(max(data['t'])/gs.dt)

t, s_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_e", ix, iy)
plot.plot_any(kind="time vs 1D(theta)",
              x=t, y=s_e,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"Edge Frostdicke bei θ_idx = {plot_theta} – Segment ({ix},{iy})",
              theta_idx=plot_theta, marker=None)
t, s_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "s_ft", ix, iy)
plot.plot_any(kind="time vs any",
              x=t, y=s_ft,
              xlabel="Zeit [s]", ylabel="Frostdicke [m]",
              title=f"F&T Frostdicke – Segment ({ix},{iy})", marker=None)
t, T_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=T_e,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"Edge Frosttemperatur bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, T_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=T_ft,
              xlabel="Zeit [s]", ylabel="Temperatur [°C]",
              title=f"F&T Frosttemperatur bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_e,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"Edge Frostdichte bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, rho_ft = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_ft", ix, iy)
plot.plot_any(kind="time vs 1D(r)",
              x=t, y=rho_ft,
              xlabel="Zeit [s]", ylabel="Dichte [kg/m^3]",
              title=f"F&T Frostdichte bei x_idx = {plot_x} – Segment ({ix},{iy})",
              r_idx=plot_x, marker=None)
t, rho_a_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=rho_a_e,
              xlabel="Zeit [s]", ylabel="Dichte der trockenen Luft [kg/m^3]",
              title=f"Edge Dichte der trockenen Luft bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
t, w_e = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e", ix, iy)
plot.plot_any(kind="time vs 2D(r,theta)",
              x=t, y=w_e,
              xlabel="Zeit [s]", ylabel="w [kg/kg]",
              title=f"Edge Feuchtigkeit bei r_idx = {plot_r} und θ_idx = {plot_theta} – Segment ({ix},{iy})",
              r_idx=plot_r, theta_idx=plot_theta, marker=None)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Edge Feuchtigkeit bei r_idx = 99 und θ_idx = 89 – Segment (0,2)'}, xlabel='Zeit [s]', ylabel='w [kg/kg]'>)

# %%
_, T_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e",      ix, iy)
plot.plot_spatial_slice(
    T_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, T_ft      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft",      ix, iy)
plot.plot_spatial_slice(
    T_ft, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"T_ft(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
)
_, rho_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_e",      ix, iy)
plot.plot_spatial_slice(
    rho_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_e [kg/m^3]", marker=None
)
_, w_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "w_e",      ix, iy)
plot.plot_spatial_slice(
    w_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"w_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="w_e [kg/kg]", marker=None
)
_, rho_a_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "rho_a_e",      ix, iy)
plot.plot_spatial_slice(
    rho_a_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
    title=f"rho_a(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="rho_a [kg/m^3]", marker=None
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 _, T_e      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_e",      ix, iy)
# ----> 2 plot.plot_spatial_slice(
#       3     T_e, vary="r", t_idx=plot_time, theta_idx=plot_theta,
#       4     title=f"T_e(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
#       5 )
#       6 _, T_ft      = plot.extract_segment_timeseries_from_snapshots(snapshots, "T_ft",      ix, iy)
#       7 plot.plot_spatial_slice(
#       8     T_ft, vary="r", t_idx=plot_time, theta_idx=plot_theta,
#       9     title=f"T_ft(r) bei t={data['t'][plot_time]} s, θ_idx = {plot_theta} – Segment ({ix},{iy})", xlabel="r_idx", ylabel="T_e [°C]", marker=None
#      10 )
#
# File ~\OneDrive\Dokumente\GitHub\MSE_VT1_luethluk\Framework\visualisation\plot.py:215, in plot_spatial_slice(y, vary, t_idx, r_idx, theta_idx, r_coords, theta_coords, title, xlabel, ylabel, save_path, show, marker, line_kwargs)
#     213     nt, nr, ntheta = y.shape
#     214     if not (0 <= t_idx < nt):
# --> 215         raise IndexError(f"t_idx {t_idx} out of bounds for time axis with size {nt}")
#     216     y_t = y[t_idx]
#     217 elif y.ndim == 2:
#
# IndexError: t_idx 119 out of bounds for time axis with size 13
